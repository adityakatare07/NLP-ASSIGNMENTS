# %% [markdown]
# sentence IS LIST OF LIST IN WHICH ANSWERS OF QUESTION 1 IS STORED

# %%
sentence=[['लगातार:O', 'किसान:O', 'इस:O', 'बाबत:O', 'जेडीए:O', 'में:O', 'आकर:O', 'योजना:O', 'को:O', 'पूर्ण:O', 'करने:O', 'के:O', 'लिये:O', 'मांग:O', 'कर:O', 'रहे:O', 'हैं:O', '।:O'],
          ['राजे:B-PER', 'छह:B-MISC', 'राज्यों:O', 'के:O', 'मुख्यमंत्रियों:O', 'के:O', 'साथ:O', 'नीति:B-ORG', 'आयोग:I-ORG', 'की:O', 'बैठक:O', 'में:O', 'भाग:O', 'लेने:O', 'दिल्ली:B-LOC', 'आईं:O', 'थीं:O', '।:O'],
          ['राजीव:B-PER', 'गाँधी:I-PER', 'ने:O', 'प्रधान:B-MISC', 'मंत्री:I-MISC', 'कार्यकाल:O', 'के:O', 'दौरान:O', 'उन्हें:O', 'उत्कृष्ट:O', 'कार्यों:O', 'के:O', 'लिए:O', 'पुरस्कृत:O', 'भी:O', 'किया:O', 'था:O', '।:O'],
          ['कई:O', 'अप्रिय:O', 'घटनाओं:O', 'से:O', 'आपका:O', 'मन:O', 'खिन्न:O', 'रह:O', 'सकता:O', 'है:O', '।:O'],
          ['यही:O', 'पानी:O', 'जीवन:O', 'की:O', 'संभावनाओं:O', 'का:O', 'पता:O', 'लगाने:O', 'में:O', 'मदद:O', 'करेगा:O', '।:O'],
          ['बता:O', 'दें:O', 'कि:O', 'विवेकानंद:B-PER', 'रेड्डी:I-PER', '(68):B-MISC', 'को:O', 'गुरुवार:B-MISC', 'को:O', 'अपने:O', 'आवास:O', 'पर:O', 'संदिग्ध:O', 'परिस्थितियों:O', 'में:O', 'मृत:O', 'पाए:O', 'गए:O', 'थे:O', '।:O'],
          ['कस्बे:O', 'का:O', 'चीनी:B-MISC', 'घी:I-MISC', 'के:O', 'थोक:O', 'व्यापारी:O', 'अनिल:B-PER', 'कंसल:I-PER', 'ने:O', 'पुलिस:O', 'को:O', 'दी:O', 'शिकायत:O', 'में:O', 'बताया:O', 'कि:O', 'वह:O', 'मंगलवार:B-MISC', 'देर:I-MISC', 'सायं:I-MISC', 'को:O', 'दुकानदारों:O', 'से:O', 'अपनी:O', 'उगाही:O', 'कर:O', 'रहा:O', 'था:O', '।:O'],
          ['यहां:O', 'वैसे:O', 'तो:O', 'कोई:O', 'जातीय:O', 'समीकरण:O', 'नहीं:O', 'है:O', '।:O', 'लेकिन:O', 'ग्रामीणों:O', 'ने:O', 'चर्चा:O', 'में:O', 'बताया:O', 'कि:O', 'इस:O', 'गांव:O', 'में:O', 'जनप्रतिनिधि:O', 'केवल:O', 'चुनाव:O', 'के:O', 'दौरान:O', 'ही:O', 'आते:O', 'हैं:O', '।:O'],
          ['रिपोर्ट:O', 'की:O', 'माने:O', 'तो:O', 'इस:O', 'पर:O', 'एक:O', 'भारतीय:O', 'अधिकारी:O', 'ने:O', 'कहा:O', 'सरकार:O', 'विदेशी:O', 'मोटरसाइकिलों:O', 'पर:O', 'आयात:O', 'शुल्क:O', 'अधिक:O', 'लगाती:O', 'है:O', 'क्यों:O', 'कि:O', 'घरेलू:O', 'उद्योग:O', 'को:O', 'सुरक्षा:O', 'देने:O', 'के:O', 'लिए:O', 'यह:O', 'जरूरी:O', 'है:O', '।:O'],
          ['ए:O', 'कृपया:O', 'अनदेखा:O', 'करें:O', 'कि:O', 'आप:O', 'कहीं:O', 'और:O', 'पढ़:O', 'सकते:O', 'हैं:O', 'कोह:O', 'टच:O', 'सिर्फ:O', 'एक:B-MISC', 'पार्टी:O', 'जगह:O', 'नहीं:O', 'है:O', '।:O', 'हां:O', 'मुख्य:O', 'क्षेत्र:O', 'में:O', 'का:O', 'फी:O', 'जीवंत:O', 'होने:O', 'की:O', 'प्रतिष्ठा:O', 'है:O', 'लेकिन:O', 'ऐसे:O', 'कई:O', 'अन्य:O', 'क्षेत्र:O', 'हैं:O', 'जो:O', 'शांतिपूर्ण:O', 'आराम:O', 'से:O', 'और:O', 'वास्तव:O', 'में:O', 'मज़ेदार:O', 'हैं:O', '।:O', 'कृपया:O', 'हमें:O', 'पढ़ें:O', 'होटल:O', 'गाइड:O', 'तथा:O', 'बीच:O', 'गाइड:O', 'अधिक:O', 'जानकारी:O', 'के:O', 'लिए:O', '।:O'],
          ['शहरी:O', 'विकास:B-ORG', 'मंत्रालय:I-ORG', 'के:O', 'सचिव:O', 'राजीव:B-PER', 'गाबा:I-PER', 'की:O', 'अध्यक्षता:O', 'में:O', 'गठित:O', 'इस:O', 'अंतर-मंत्रालयी:B-ORG', 'समिति:I-ORG', 'ने:O', 'शहर:O', 'में:O', 'फ्लाई:O', 'ओवर:O', 'के:O', 'निर्माण:O', 'के:O', 'बजाय:O', 'मौजूदा:O', 'सड़कों:O', 'के:O', 'सही:O', 'इस्तेमाल:O', 'और:O', 'यातायात:O', 'प्रबंधन:O', 'पर:O', 'जोर:O', 'दिया:O', 'है:O', '।:O'],
          ['लीग:O', 'के:O', 'सीजन-5:O', 'के:O', 'मैचों:O', 'की:O', 'टीआरपी:O', 'ने:O', 'हाल:O', 'ही:O', 'में:O', 'भारत:B-ORG', 'और:O', 'श्रीलंका:I-ORG', 'के:O', 'बीच:O', 'हुई:O', 'टेस्ट:O', 'सीरीज:O', 'के:O', 'दर्शकों:O', 'की:O', 'संख्या:O', 'को:O', 'पीछे:O', 'कर:O', 'दिया:O', '।:O'],
          ['दूसरा:B-MISC', 'पहलू:O', 'है:O', 'क़ानून:-व्यवस्था:O', 'के:O', 'संभालने:O', 'में:O', 'राज्य:O', 'और:O', 'स्थानीय:O', 'प्रशासन:O', 'की:O', 'विफलता:O', '।:O'],
          ['वहीं:O', 'आईसीआईसीआई:B-ORG', 'बैंक:I-ORG', 'के:O', 'लिए:O', 'ब्रोकरेज:B-ORG', 'फर्म:I-ORG', 'ने:O', 'रेटिंग:O', 'इक्वल-वेट:O', 'से:O', 'घटाकर:O', 'अंडरवेट:O', 'करने:O', 'के:O', 'साथ:O', 'साथ:O', 'वित्त:B-MISC', 'वर्ष:I-MISC', '2018:I-MISC', 'और:O', 'वित्त:B-MISC', 'वर्ष:I-MISC', '2019:I-MISC', 'के:O', 'लिए:O', 'आय:O', 'अनुमानों:O', 'को:O', '7:B-MISC', 'और:O', '5:B-MISC', 'प्रतिशत:O', 'तक:O', 'घटा:O', 'दिया:O', 'है:O', '।:O'],
          ['ऑस्ट्रेलिया:B-ORG', 'ने:O', 'पहले:O', 'बल्लेबाजी:O', 'करते:O', 'हुए:O', 'निर्धारित:O', '50:B-MISC', 'ओवर:O', 'में:O', '272:B-MISC', 'रनों:O', 'का:O', 'विशाल:O', 'स्कोर:O', 'खड़ा:O', 'किया:O', 'था:O', '।:O', 'सचिन:B-PER', 'की:O', 'लाजवाब:O', 'पारी:O', 'के:O', 'दम:O', 'पर:O', 'भारत:B-ORG', 'ने:O', 'यह:O', 'स्कोर:O', 'सिर्फ:O', '48.3:B-MISC', 'ओवर:O', 'में:O', '275:B-MISC', 'रन:O', 'बनाकर:O', 'हासिल:O', 'कर:O', 'लिया:O', 'था:O', '।:O'],
          ['या:O', 'गाण्यांच्या:O', 'लाँचिंगमध्ये:O', 'शिवसेना:B-MISC', 'पक्षप्रमुख:I-MISC', 'उद्धव:B-PER', 'ठाकरे:I-PER', 'रश्मी:B-PER', 'ठाकरे:I-PER', 'आदित्य:B-PER', 'ठाकरे:I-PER', 'आणि:O', 'सिनेमातील:O', 'कलाकर:O', 'नवाजुद्दीन:B-PER', 'सिद्दिकी:I-PER', 'अमृता:B-PER', 'राव:I-PER', 'यांच्यासह:O', 'इतर:O', 'मंडळींनीही:O', 'हाजेरी:O', 'लावली:O', 'होती:O', 'है:O', '।:O'],
          ['कंपनी:O', 'फिलहाल:O', 'अपने:O', 'ट्रांसमिशन:B-MISC', 'कारोबार:I-MISC', 'को:O', 'बेचने:O', 'पर:O', 'विचार:O', 'कर:O', 'रही:O', 'है:O', '।:O'],
          ['इस:O', 'तरह:O', 'इसमें:O', 'खेल:O', 'रहे:O', 'हर:O', 'दूसरे:O', 'खिलाड़ी:O', 'के:O', 'डोप:O', 'परीक्षण:O', 'की:O', 'मुकम्मल:O', 'व्यवस्था:O', 'तैयार:O', 'कर:O', 'ली:O', 'गई:O', 'है:O', '।:O'],
          ['इस:O', 'बार:O', 'गुरुवार:B-MISC', 'को:O', 'ईसाई:B-ORG', 'समुदाय:O', 'के:O', 'लोगों:O', 'ने:O', 'यहां:O', 'मुर्दों:B-MISC', 'की:I-MISC', 'ईद:I-MISC', 'मनाई:O', '।:O'],
          ['अगर:O', 'जनता:O', 'इनको:O', 'गंभीरता:O', 'से:O', 'लेगी:O', 'तो:O', 'निश्चित:O', 'तौर:O', 'पर:O', 'चुनाव:O', 'में:O', 'इन:O', 'मुद्दों:O', 'की:O', 'गूंज:O', 'सुनाई:O', 'देने:O', 'लगेगी:O', '।:O'],
          ['मशीन:O', 'के:O', 'माध्यम:O', 'से:O', 'इसकी:O', 'पैकिंग:O', 'ऑटोमेटिक:O', 'रूप:O', 'से:O', 'होती:O', 'है:O', 'जिसमें:O', 'अगरबत्तियों:O', 'की:O', 'गिनती:O', 'होते:O', 'हुए:O', 'प्लास्टिक:O', 'पाउच:O', 'में:O', 'भरने:O', 'की:O', 'प्रक्रिया:O', 'अपने:O', 'आप:O', 'होती:O', 'है:O', 'अन्यथा:O', 'एक:O', 'अगरबत्ती:O', 'की:O', 'गिनती:O', 'के:O', 'लिए:O', 'मैन्युअल:O', 'मशीन:O', 'भी:O', 'आती:O', 'है:O', 'जिससे:O', 'सिर्फ:O', 'अगरबत्ती:O', 'की:O', 'गिनती:O', 'होती:O', 'है:O', 'बाकि:O', 'प्रक्रिया:O', 'हाथों:O', 'के:O', 'माध्यम:O', 'से:O', 'होती:O', 'है:O', '।:O'],
          ['जबकि:O', 'राज्यसभा:B-ORG', 'के:O', 'द्वारा:O', 'पारित:O', 'विधेयक:O', 'या:O', 'प्रस्ताव:O', 'लोकसभा:B-ORG', 'के:O', 'भंग:O', 'होने:O', 'की:O', 'स्थिति:O', 'में:O', 'समाप्त:O', 'नहीं:O', 'होते:O', 'हैं:O', '।:O'],
          ['उत्तर:B-LOC', 'प्रदेश:I-LOC', 'में:O', ',मऊ:B-LOC', 'के:O', 'मोहम्मदाबाद:B-LOC', 'गोहना:I-LOC', 'कोतवाली:I-LOC', 'क्षेत्र:O', 'बंद:O', 'रेलवे:O', 'क्रासिंग:O', 'को:O', 'पहले:O', 'पार:O', 'करने;O', 'में:O', 'हुये:O', 'मामूली:O', 'विवाद:O', 'में:O', 'एक:O', 'युवक:O', 'को:O', 'गोली:O', 'मार:O', 'दी:O', 'गयी:O,।:O'],
          ['उन्होंने:O', 'कहा:O', 'कि:O', 'वह:O', 'सरकार:O', 'को:O', 'अस्थिर:O', 'करने:O', 'के:O', 'लिए:O', 'कोई:O', 'खेल:O', 'नहीं:O', 'खेल:O', 'रहे:O', 'हैं:O','।:O'],
          ['टीवी:O', 'सीरियर:O', 'और:O', 'फिल्मों:O , में:O', 'रावण:B-PER', 'को:O', ',बहुत:O', 'डरावना:O', 'बताया:O', 'गया:O', 'है:O', 'लेकिन:O', 'वास्तव:O', 'में:O', 'ऐसा:O', 'नहीं:O', 'था:O','।:O']]

# %% [markdown]
# tokenizer_outputs IS LIST OF LIST IN WHICH OUTPUT GIVEN BY CHATGPT IS STORED

# %%
tokenizer_outputs = [['लगातार:O', 'किसान:O', 'इस:O', 'बाबत:O', 'जेडीए:O', 'में:O', 'आकर:O', 'योजना:O', 'को:O', 'पूर्ण:O', 'करने:O', 'के:O', 'लिये:O', 'मांग:O', 'कर:O', 'रहे:O', 'हैं:O','।:O'],
                     ['राजे:O', 'छह:O', 'राज्यों:O', 'के:O', 'मुख्यमंत्रियों:O', 'के:O', 'साथ:O', 'नीति:O', 'आयोग:O', 'की:O', 'बैठक:O', 'में:O', 'भाग:O', 'लेने:O', 'दिल्ली:B-LOC', 'आईं:I-LOC', 'थी:O','।:O'],
                     ['राजीव:B-PER', 'गाँधी:I-PER', 'ने:O', 'प्रधान:O', 'मंत्री:O', 'कार्यकाल:O', 'के:O', 'दौरान:O', 'उन्हें:O', 'उत्कृष्ट:O', 'कार्यों:O', 'के:O', 'लिए:O', 'पुरस्कृत:O', 'भी:O', 'किया:O', 'था:O', '.:O'],
                     ['कई:O', 'अप्रिय:O', 'घटनाओं:O', 'से:O', 'आपका:O', 'मन:O', 'खिन्न:O', 'रह:O', 'सकता:O', 'है:O', '।:O'],
                     ['यही:O', 'पानी:O', 'जीवन:O', 'की:O', 'संभावनाओं:O', 'का:O', 'पता:O', 'लगाने:O', 'में:O', 'मदद:O', 'करेगा:O', '।:O'],
                     ['बता:O', 'दें:O', 'कि:O', ',:O', 'विवेकानंद:O', 'रेड्डी:O', '(68):O', 'को:O', 'गुरुवार:O', 'को:O', 'अपने:O', 'आवास:O', 'पर:O', 'संदिग्ध:O', 'परिस्थितियों:O', 'में:O', 'मृत:O', 'पाए:गए', 'थे:O', '।:O'],
                     ['कस्बे:O', 'का:O', 'चीनी:O', 'घी:O', 'के:O', 'थोक:O', 'व्यापारी:O', 'अनिल:B-PER', 'कंसल:I-PER', 'ने:O', 'पुलिस:O', 'को:O', 'दी:O', 'शिकायत:O', 'में:O', 'बताया:O', 'कि:O', 'वह:O', 'मंगलवार:O', 'देर:O', 'सायं:O', 'को:O', 'दुकानदारों:O', 'से:O', 'अपनी:O', 'उगाही:O', 'कर:O','रहा:O', 'था:O', '।:O'],
                     ['यहां:O', 'वैसे:O', 'तो:O', 'कोई:O', 'जातीय:O', 'समीकरण:O', 'नहीं:O', 'है:O', '।:O', 'लेकिन:O', 'ग्रामीणों:O', 'ने:O', 'चर्चा:O', 'में:O', 'बताया:O', 'कि:O', 'इस:O', 'गांव:O', 'में:O', 'जनप्रतिनिधि:O', 'केवल:O', 'चुनाव:O', 'के:O', 'दौरान:O', 'ही:O', 'आते:O', 'हैं:O', '।:O'],
                     ['रिपोर्ट:O', 'की:O', 'माने:O', 'तो:O', 'इस:O', 'पर:O', 'एक:O', 'भारतीय:O', 'अधिकारी:O', 'ने:O', 'कहा:O', 'सरकार:O', 'विदेशी:O', 'मोटरसाइकिलों:O', 'पर:O', 'आयात:O', 'शुल्क:O', 'अधिक:O', 'लगाती:O', 'है:O', 'क्योंकि:O', 'घरेलू:O', 'उद्योग:O', 'को:O', 'सुरक्षा:O', 'देने:O', 'के:O', 'लिए:O', 'यह:O', 'जरूरी:O', 'है:O', '।:O'],
                     ['ए::O', 'कृपया:O', 'अनदेखा:O', 'करें:O', 'कि:O', 'आप:O', 'कहीं:O', 'और:O', 'पढ़:O', 'सकते:O', 'हैं:O', '-:O', 'कोह:O', 'टच:O', 'सिर्फ:O', 'एक:O', 'पार्टी:O', 'जगह:O', 'नहीं:O', 'हैं:O', '!:O', 'हां:O', ',:O', 'मुख्य:O', 'क्षेत्र:O', 'में:O', 'काफी:O', 'जीवंत:O', 'होने:O', 'की:O', 'प्रतिष्ठा:O', 'हैं:O', ',:O', 'लेकिन:O', 'ऐसे:O', 'कई:O', 'अन्य:O', 'क्षेत्र:O', 'हैं:O', 'जो:O', 'शांतिपूर्ण:O', ',:O', 'आराम:O', 'से:O', 'और:O', 'वास्तव:O', 'में:O', 'मज़ेदार:O', 'हैं:O', '।:O', 'कृपया:O', 'हमें:O', 'पढ़ें:O', 'होटल:O', 'गाइड:O', 'तथा:O', 'बीच:O', 'गाइड:O', 'अधिक:O', 'जानकारी:O', 'के:O', 'लिए:O', '।:O'],
                     ['शहरी:O', 'विकास:O', 'मंत्रालय:O', 'के:O', 'सचिव:B-PER', 'राजीव:I-PER', 'गाबा:I-PER', 'की:O', 'अध्यक्षता:O', 'में:O', 'गठित:O', 'इस:O', 'अंतर-मंत्रालयी:O', 'समिति:O', 'ने:O', 'शहर:O', 'में:O', 'फ्लाई-:O', 'ओवर:O', 'के:O', 'निर्माण:O', 'के:O', 'बजाय:O', 'मौजूदा:O', 'सड़कों:O', 'के:O', 'सही:O', 'इस्तेमाल:O', 'और:O', 'यातायात:O', 'प्रबंधन:O', 'पर:O', 'जोर:O', 'दिया:O', 'है:।'],
                     ['लीग:O', 'के:O', 'सीजन-5:O', 'के:O', 'मैचों:O', 'की:O', 'टीआरपी:O', 'ने:O', 'हाल:O', 'ही:O', 'में:O', 'भारत:O', 'और:O', 'श्रीलंका:O', 'के:O', 'बीच:O', 'हुई:O', 'टेस्ट:O', 'सीरीज:O', 'के:O', 'दर्शकों:O', 'की:O', 'संख्या:O', 'को:O', 'पीछे:O', 'कर:O', 'दिया:O', '।:O'],
                     ['दूसरा:O', 'पहलू:O', 'है-:O', 'क़ानून-व्यवस्था:O', 'के:O', 'संभालने:O', 'में:O', 'राज्य:O', 'और:O', 'स्थानीय:O', 'प्रशासन:O', 'की:O', 'विफलता:O', '।:O'],
                     ['वहीं:O', 'आईसीआईसीआई:B-ORG', 'बैंक:I-ORG', 'के:O', 'लिए:O', 'ब्रोकरेज:O', 'फर्म:O', 'ने:O', 'रेटिंग:O', 'इक्वल-वेट:O', 'से:O', 'घटाकर:O', 'अंडरवेट:O', 'करने:O', 'के:O', 'साथ:O', 'साथ:O', 'वित्त:O', 'वर्ष:O', '2018:O', 'और:O', 'वित्त:O', 'वर्ष:O', '2019:O', 'के:O', 'लिए:O', 'आय:O', 'अनुमानों:O', 'को:O', '7:O', 'और:O', '5:O', 'प्रतिशत:O', 'तक:O', 'घटा:O', 'दिया:O', 'है:।'],
                     ['ऑस्ट्रेलिया:B-LOC', 'ने:O', 'पहले:O', 'बल्लेबाजी:O', 'करते:O', 'हुए:O', 'निर्धारित:O', '50:O', 'ओवर:O', 'में:O', '272:O', 'रनों:O', 'का:O', 'विशाल:O', 'स्कोर:O', 'खड़ा:O', 'किया:O', 'था।:O', 'सचिन:B-PER', 'की:O', 'लाजवाब:O', 'पारी:O', 'के:O', 'दम:O', 'पर:O', 'भारत:O', 'ने:O', 'यह:O', 'स्कोर:O', 'सिर्फ:O', '48.3:O', 'ओवर:O', 'में:O', '275:O', 'रन:O', 'बनाकर:O', 'हासिल:O', 'कर:O', 'लिया:O', 'था:।'],
                     ['या:O', 'गाण्यांच्या:O', 'लाँचिंगमध्ये:O', 'शिवसेना:B-ORG', 'पक्षप्रमुख:O', 'उद्धव:B-PER', 'ठाकरे:I-PER', ',:O', 'रश्मी:B-PER', 'ठाकरे:I-PER', ',:O', 'आदित्य:B-PER', 'ठाकरे:I-PER', 'आणि:O', 'सिनेमातील:O', 'कलाकर:O', 'नवाजुद्दीन:B-PER', 'सिद्दिकी:I-PER', ',:O', 'अमृता:B-PER', 'राव:I-PER', 'यांच्यासह:O', 'इतर:O', 'मंडळींनीही:O', 'हाजेरी:O', 'लावली:O', 'होती:O', '।:O'],
                     ['कंपनी:O', 'फिलहाल:O', 'अपने:O', 'ट्रांसमिशन:B-MISC', 'कारोबार:I-MISC', 'को:O', 'बेचने:O', 'पर:O', 'विचार:O', 'कर:O', 'रही:O', 'है:O', '।:O'],
                     ['इस:O', 'तरह:O', 'इसमें:O', 'खेल:O', 'रहे:O', 'हर:O', 'दूसरे:O', 'खिलाड़ी:O', 'के:O', 'डोप:O', 'परीक्षण:O', 'की:O', 'मुकम्मल:O', 'व्यवस्था:O', 'तैयार:O', 'कर:O', 'ली:O', 'गई:O', 'है:O', '।:O'],
                     ['इस:O', 'बार:O', 'गुरुवार:O', 'को:O', 'ईसाई:O', 'समुदाय:O', 'के:O', 'लोगों:O', 'ने:O', 'यहां:O', '‘मुर्दों:O', 'की:O', 'ईद’:O', 'मनाई:O', '।:O'],
                     ['अगर:O', 'जनता:O', 'इनको:O', 'गंभीरता:O', 'से:O', 'लेगी:O', 'तो:O', 'निश्चित:O', 'तौर:O', 'पर:O', 'चुनाव:O', 'में:O', 'इन:O', 'मुद्दों:O', 'की:O', 'गूंज:O', 'सुनाई:O', 'देने:O', 'लगेगी:O', '।:O'],
                     ['मशीन:O', 'के:O', 'माध्यम:O', 'से:O', 'इसकी:O', 'पैकिंग:O', 'ऑटोमेटिक:O', 'रूप:O', 'से:O', 'होती:O', 'है:O', 'जिसमें:O', 'अगरबत्तियों:O', 'की:O', 'गिनती:O', 'होते:O', 'हुए:O', 'प्लास्टिक:O', 'पाउच:O', 'में:O', 'भरने:O', 'की:O', 'प्रक्रिया:O', 'अपने:O', 'आप:O', 'होती:O', 'है:O', ',:O', 'अन्यथा:O', 'एक:O', 'अगरबत्ती:O', 'की:O', 'गिनती:O', 'के:O', 'लिए:O', 'मैन्युअल:O', 'मशीन:O', 'भी:O', 'आती:O', 'है:O', 'जिससे:O', 'सिर्फ:O', 'अगरबत्ती:O', 'की:O', 'गिनती:O', 'होती:O', 'है:O', 'बाकि:O', 'प्रक्रिया:O', 'हाथों:O', 'के:O', 'माध्यम:O', 'से:O', 'होती:O', 'है:O', '।:O'],
                     ['जबकि:O', 'राज्यसभा:O', 'के:O', 'द्वारा:O', 'पारित:O', 'विधेयक:O', 'या:O', 'प्रस्ताव:O', 'लोकसभा:O', 'के:O', 'भंग:O', 'होने:O', 'की:O', 'स्थिति:O', 'में:O', 'समाप्त:O', 'नहीं:O', 'होते:O', 'हैं:O', '।:O'],
                     ['उत्तर:B-LOC', 'प्रदेश:I-LOC', 'में:O', 'मऊ:O', 'के:O', 'मोहम्मदाबाद:O', 'गोहना:O', 'कोतवाली:O', 'क्षेत्र:O', 'बंद:O', 'रेलवे:O', 'क्रासिंग:O', 'को:O', 'पहले:O', 'पार:O', 'करने:O', 'में:O', 'हुए:O', 'मामूली:O', 'विवाद:O', 'में:O', 'एक:O', 'युवक:O', 'को:O', 'गोली:O', 'मार:O', 'दी:O', 'गई:O', '।:O'],
                     ['उन्होंने:O', 'कहा:O', 'कि:O', 'वह:O', 'सरकार:O', 'को:O', 'अस्थिर:O', 'करने:O', 'के:O', 'लिए:O', 'कोई:O', 'खेल:O', 'नहीं:O', 'खेल:O', 'रहे:O', 'हैं:O', '।:O'],
                     ['टीवी:B-MISC', 'सीरियल:O', 'और:O', 'फिल्मों:O', 'में:O', 'रावण:B-PER', 'को:O', 'बहुत:O', 'डरावना:O', 'बताया:O', 'गया:O', 'है,:O', 'लेकिन:O', 'वास्तव:O', 'में:O', 'ऐसा:O', 'नहीं:O','था:O','।:O']]

# %% [markdown]
# list IS LIST OF LIST IN WHICH EACH WORD IS STORED AS 'लगातार:O:O' WHERE लगातार IS WORD O NER TAG GIVEN BY US ANS O NER TAG GIVEN BY CHATGPT

# %%
list=[
      ['लगातार:O:O', 'किसान:O:O', 'इस:O:O', 'बाबत:O:O', 'जेडीए:O:O', 'में:O:O', 'आकर:O:O', 'योजना:O:O', 'को:O:O', 'पूर्ण:O:O', 'करने:O:O', 'के:O:O', 'लिये:O:O', 'मांग:O:O', 'कर:O:O', 'रहे:O:O', 'हैं:O:O', '।:O:O'],
      ['राजे:B-PER:O', 'छह:B-MISC:O', 'राज्यों:O:O', 'के:O:O', 'मुख्यमंत्रियों:O:O', 'के:O:O', 'साथ:O:O', 'नीति:B-ORG:O', 'आयोग:I-ORG:O', 'की:O:O', 'बैठक:O:O', 'में:O:O', 'भाग:O:O', 'लेने:O:O', 'दिल्ली:B-LOC:B-LOC', 'आईं:O:I-LOC', 'थीं:O:O', '।:O:O'],
      ['राजीव:B-PER:B-PER', 'गाँधी:I-PER:I-PER', 'ने:O:O', 'प्रधान:B-MISC:O', 'मंत्री:I-MISC:O', 'कार्यकाल:O:O', 'के:O:O', 'दौरान:O:O', 'उन्हें:O:O', 'उत्कृष्ट:O:O', 'कार्यों:O:O', 'के:O:O', 'लिए:O:O', 'पुरस्कृत:O:O', 'भी:O:O', 'किया:O:O', 'था:O:O', '।:O:O'],
      ['कई:O:O', 'अप्रिय:O:O', 'घटनाओं:O:O', 'से:O:O', 'आपका:O:O', 'मन:O:O', 'खिन्न:O:O', 'रह:O:O', 'सकता:O:O', 'है:O:O', '।:O:O'],
      ['यही:O:O', 'पानी:O:O', 'जीवन:O:O', 'की:O:O', 'संभावनाओं:O:O', 'का:O:O', 'पता:O:O', 'लगाने:O:O', 'में:O:O', 'मदद:O:O', 'करेगा:O:O', '।:O:O'],
      ['बता:O:O', 'दें:O:O', 'कि:O:O', 'विवेकानंद:B-PER:O', 'रेड्डी:I-PER:O', '(68):B-MISC:O', 'को:O:O', 'गुरुवार:B-MISC:O', 'को:O:O', 'अपने:O:O', 'आवास:O:O', 'पर:O:O', 'संदिग्ध:O:O', 'परिस्थितियों:O:O', 'में:O:O', 'मृत:O:O', 'पाए:O:O', 'थे:O:O', '।:O:O'],
      ['कस्बे:O:O', 'का:O:O', 'चीनी:B-MISC:O', 'घी:I-MISC:O', 'के:O:O', 'थोक:O:O', 'व्यापारी:O:O', 'अनिल:B-PER:B-PER', 'कंसल:I-PER:I-PER', 'ने:O:O', 'पुलिस:O:O', 'को:O:O', 'दी:O:O', 'शिकायत:O:O', 'में:O:O', 'बताया:O:O', 'कि:O:O', 'वह:O:O', 'मंगलवार:B-MISC:O', 'देर:I-MISC:O', 'सायं:I-MISC:O', 'को:O:O', 'दुकानदारों:O:O', 'से:O:O', 'अपनी:O:O', 'उगाही:O:O', 'कर:O:O','रहा:O:O', 'था:O:O', '।:O:O'],
      ['यहां:O:O', 'वैसे:O:O', 'तो:O:O', 'कोई:O:O', 'जातीय:O:O', 'समीकरण:O:O', 'नहीं:O:O', 'है:O:O', '।:O:O', 'लेकिन:O:O', 'ग्रामीणों:O:O', 'ने:O:O', 'चर्चा:O:O', 'में:O:O', 'बताया:O:O', 'कि:O:O', 'इस:O:O', 'गांव:O:O', 'में:O:O', 'जनप्रतिनिधि:O:O', 'केवल:O:O', 'चुनाव:O:O', 'के:O:O', 'दौरान:O:O', 'ही:O:O', 'आते:O:O', 'हैं:O:O', '।:O:O'],
      ['रिपोर्ट:O:O', 'की:O:O', 'माने:O:O', 'तो:O:O', 'इस:O:O', 'पर:O:O', 'एक:O:O', 'भारतीय:O:O', 'अधिकारी:O:O', 'ने:O:O', 'कहा:O:O', 'सरकार:O:O', 'विदेशी:O:O', 'मोटरसाइकिलों:O:O', 'पर:O:O', 'आयात:O:O', 'शुल्क:O:O', 'अधिक:O:O', 'लगाती:O:O', 'है:O:O', 'क्योंकि:O:O', 'घरेलू:O:O', 'उद्योग:O:O', 'को:O:O', 'सुरक्षा:O:O', 'देने:O:O', 'के:O:O', 'लिए:O:O', 'यह:O:O', 'जरूरी:O:O', 'है:O:O', '।:O:O'],
      ['ए:O:O', 'कृपया:O:O', 'अनदेखा:O:O', 'करें:O:O', 'कि:O:O', 'आप:O:O', 'कहीं:O:O', 'और:O:O', 'पढ़:O:O', 'सकते:O:O', 'हैं:O:O', 'कोह:O:O', 'टच:O:O', 'सिर्फ:O:O', 'एक:B-MISC:O', 'पार्टी:O:O', 'जगह:O:O', 'नहीं:O:O', 'हैं:O:O', '।:O:O', 'हां:O:O', 'मुख्य:O:O', 'क्षेत्र:O:O', 'में:O:O', 'का:O:O', 'फी:O:O', 'जीवंत:O:O', 'होने:O:O', 'की:O:O', 'प्रतिष्ठा:O:O', 'है:O:O', 'लेकिन:O:O', 'ऐसे:O:O', 'कई:O:O', 'अन्य:O:O', 'क्षेत्र:O:O', 'हैं:O:O', 'जो:O:O'],
      ['शहरी:O:O', 'विकास:B-ORG:O', 'मंत्रालय:I-ORG:O', 'के:O:O', 'सचिव:O:B-PER', 'राजीव:B-PER:I-PER', 'गाबा:I-PER:I-PER', 'की:O:O', 'अध्यक्षता:O:O', 'में:O:O', 'गठित:O:O', 'इस:O:O', 'अंतर-मंत्रालयी:B-ORG:O', 'समिति:I-ORG:O', 'ने:O:O', 'शहर:O:O', 'में:O:O', 'फ्लाई:O:O', 'ओवर:O:O', 'के:O:O', 'निर्माण:O:O', 'के:O:O', 'बजाय:O:O', 'मौजूदा:O:O', 'सड़कों:O:O', 'के:O:O', 'सही:O:O', 'इस्तेमाल:O:O', 'और:O:O', 'यातायात:O:O', 'प्रबंधन:O:O', 'पर:O:O', 'जोर:O:O', 'दिया:O:O', 'है:O:O', '।:O:O'],
      ['लीग:O:O', 'के:O:O', 'सीजन-5:O:O', 'के:O:O', 'मैचों:O:O', 'की:O:O', 'टीआरपी:O:O', 'ने:O:O', 'हाल:O:O', 'ही:O:O', 'में:O:O', 'भारत:B-ORG:O', 'और:O:O', 'श्रीलंका:I-ORG:O', 'के:O:O', 'बीच:O:O', 'हुई:O:O', 'टेस्ट:O:O', 'सीरीज:O:O', 'के:O:O', 'दर्शकों:O:O', 'की:O:O', 'संख्या:O:O', 'को:O:O', 'पीछे:O:O', 'कर:O:O', 'दिया:O:O', '।:O:O'],
      ['दूसरा:O:O', 'पहलू:O:O', 'है-:O:O', 'क़ानून-व्यवस्था:O:O', 'के:O:O', 'संभालने:O:O', 'में:O:O', 'राज्य:O:O', 'और:O:O', 'स्थानीय:O:O', 'प्रशासन:O:O', 'की:O:O', 'विफलता:O:O', '।:O:O'],
      ['वहीं:O:O', 'आईसीआईसीआई:B-ORG:B-ORG', 'बैंक:I-ORG:I-ORG', 'के:O:O', 'लिए:O:O', 'ब्रोकरेज:B-ORG:O', 'फर्म:I-ORG:O', 'ने:O:O', 'रेटिंग:O:O', 'इक्वल-वेट:O:O', 'से:O:O', 'घटाकर:O:O', 'अंडरवेट:O:O', 'करने:O:O', 'के:O:O', 'साथ:O:O', 'साथ:O:O', 'वित्त:B-MISC:O', 'वर्ष:I-MISC:O', '2018:I-MISC:O', 'और:O:O', 'वित्त:B-MISC:O', 'वर्ष:I-MISC:O', '2019:I-MISC:O', 'के:O:O', 'लिए:O:O', 'आय:O:O', 'अनुमानों:O:O', 'को:O:O', '7:B-MISC:O', 'और:O:O', '5:B-MISC:O', 'प्रतिशत:O:O', 'तक:O:O', 'घटा:O:O', 'दिया:O:O', 'है:O:O', '।:O:O'],
      ['ऑस्ट्रेलिया:B-ORG:B-LOC', 'ने:O:O', 'पहले:O:O', 'बल्लेबाजी:O:O', 'करते:O:O', 'हुए:O:O', 'निर्धारित:O:O', '50:B-MISC:O', 'ओवर:O:O', 'में:O:O', '272:B-MISC:O', 'रनों:O:O', 'का:O:O', 'विशाल:O:O', 'स्कोर:O:O', 'खड़ा:O:O', 'किया:O:O', 'था:O:O', '।:O:O', 'सचिन:B-PER:O', 'की:O:O', 'लाजवाब:O:O', 'पारी:O:O', 'के:O:O', 'दम:O:O', 'पर:O:O', 'भारत:B-ORG:O', 'ने:O:O', 'यह:O:O', 'स्कोर:O:O', 'सिर्फ:O:O', '48.3:B-MISC:O', 'ओवर:O:O', 'में:O:O', '275:B-MISC:O', 'रन:O:O', 'बनाकर:O:O', 'हासिल:O:O', 'कर:O:O', 'लिया:O:O', 'था:O:O', '।:O:O'],
      ['या:O:O', 'गाण्यांच्या:O:O', 'लाँचिंगमध्ये:O:O', 'शिवसेना:B-MISC:B-ORG', 'पक्षप्रमुख:I-MISC:O', 'उद्धव:B-PER:B-PER', 'ठाकरे:I-PER:I-PER', 'रश्मी:B-PER:B-PER', 'ठाकरे:I-PER:I-PER', 'आदित्य:B-PER:B-PER', 'ठाकरे:I-PER:I-PER', 'आणि:O:O', 'सिनेमातील:O:O', 'कलाकर:O:O', 'नवाजुद्दीन:B-PER:B-PER', 'सिद्दिकी:I-PER:I-PER', 'अमृता:B-PER:B-PER', 'राव:I-PER:I-PER', 'यांच्यासह:O:O', 'इतर:O:O', 'मंडळींनीही:O:O', 'हाजेरी:O:O', 'लावली:O:O', 'होती:O:O', '।:O:O'],
      ['कंपनी:O:O', 'फिलहाल:O:O', 'अपने:O:O', 'ट्रांसमिशन:B-MISC:B-MISC', 'कारोबार:I-MISC:I-MISC', 'को:O:O', 'बेचने:O:O', 'पर:O:O', 'विचार:O:O', 'कर:O:O', 'रही:O:O', 'है:O:O', '।:O:O'],
      ['इस:O:O', 'तरह:O:O', 'इसमें:O:O', 'खेल:O:O', 'रहे:O:O', 'हर:O:O', 'दूसरे:O:O', 'खिलाड़ी:O:O', 'के:O:O', 'डोप:O:O', 'परीक्षण:O:O', 'की:O:O', 'मुकम्मल:O:O', 'व्यवस्था:O:O', 'तैयार:O:O', 'कर:O:O', 'ली:O:O', 'गई:O:O', 'है:O:O', '।:O:O'],
      ['कंपनी:O:O', 'फिलहाल:O:O', 'अपने:O:O', 'ट्रांसमिशन:B-MISC:B-MISC', 'कारोबार:I-MISC:I-MISC', 'को:O:O', 'बेचने:O:O', 'पर:O:O', 'विचार:O:O', 'कर:O:O', 'रही:O:O', 'है:O:O', '।:O:O'],
      ['अगर:O:O', 'जनता:O:O', 'इनको:O:O', 'गंभीरता:O:O', 'से:O:O', 'लेगी:O:O', 'तो:O:O', 'निश्चित:O:O', 'तौर:O:O', 'पर:O:O', 'चुनाव:O:O', 'में:O:O', 'इन:O:O', 'मुद्दों:O:O', 'की:O:O', 'गूंज:O:O', 'सुनाई:O:O', 'देने:O:O', 'लगेगी:O:O', '।:O:O'],
      ['मशीन:O:O', 'के:O:O', 'माध्यम:O:O', 'से:O:O', 'इसकी:O:O', 'पैकिंग:O:O', 'ऑटोमेटिक:O:O', 'रूप:O:O', 'से:O:O', 'होती:O:O', 'है:O:O', 'जिसमें:O:O', 'अगरबत्तियों:O:O', 'की:O:O', 'गिनती:O:O', 'होते:O:O', 'हुए:O:O', 'प्लास्टिक:O:O', 'पाउच:O:O', 'में:O:O', 'भरने:O:O', 'की:O:O', 'प्रक्रिया:O:O', 'अपने:O:O', 'आप:O:O', 'होती:O:O', 'है:O:O', '।:O:O', ',:O:O', 'अन्यथा:O:O', 'एक:O:O', 'अगरबत्ती:O:O', 'की:O:O', 'गिनती:O:O', 'के:O:O', 'लिए:O:O', 'मैन्युअल:O:O', 'मशीन:O:O', 'भी:O:O', 'आती:O:O', 'है:O:O', 'जिससे:O:O', 'सिर्फ:O:O', 'अगरबत्ती:O:O', 'की:O:O', 'गिनती:O:O', 'होती:O:O', 'है:O:O', 'बाकि:O:O', 'प्रक्रिया:O:O', 'हाथों:O:O', 'के:O:O', 'माध्यम:O:O', 'से:O:O', 'होती:O:O', 'है:O:O', '।:O:O'],
      ['जबकि:O:O', 'राज्यसभा:B-ORG:O', 'के:O:O', 'द्वारा:O:O', 'पारित:O:O', 'विधेयक:O:O', 'या:O:O', 'प्रस्ताव:O:O', 'लोकसभा:B-ORG:O', 'के:O:O', 'भंग:O:O', 'होने:O:O', 'की:O:O', 'स्थिति:O:O', 'में:O:O', 'समाप्त:O:O', 'नहीं:O:O', 'होते:O:O', 'हैं:O:O', '।:O:O'],
      ['उत्तर:B-LOC:B-LOC', 'प्रदेश:I-LOC:I-LOC', 'में:O:O', ',मऊ:B-LOC:O', 'के:O:O', 'मोहम्मदाबाद:B-LOC:O', 'गोहना:I-LOC:O', 'कोतवाली:I-LOC:O', 'क्षेत्र:O:O', 'बंद:O:O', 'रेलवे:O:O', 'क्रासिंग:O:O', 'को:O:O', 'पहले:O:O', 'पार:O:O', 'करने:O:O', 'में:O:O', 'हुये:O:O', 'मामूली:O:O', 'विवाद:O:O', 'में:O:O', 'एक:O:O', 'युवक:O:O', 'को:O:O', 'गोली:O:O', 'मार:O:O', 'दी:O:O', 'गयी:O:O', ',।:O:O'],
      ['उन्होंने:O:O', 'कहा:O:O', 'कि:O:O', 'वह:O:O', 'सरकार:O:O', 'को:O:O', 'अस्थिर:O:O', 'करने:O:O', 'के:O:O', 'लिए:O:O', 'कोई:O:O', 'खेल:O:O', 'नहीं:O:O', 'खेल:O:O', 'रहे:O:O', 'हैं:O:O', '।:O:O'],
      ['टीवी:O:B-MISC', 'सीरियर:O:O', 'और:O:O', 'फिल्मों:O:O', ',:O:O', 'में:O:O', 'रावण:B-PER:B-PER', 'को:O:O', ',बहुत:O:O', 'डरावना:O:O', 'बताया:O:O', 'गया:O:O', 'है:O:O', 'लेकिन:O:O', 'वास्तव:O:O', 'में:O:O', 'ऐसा:O:O', 'नहीं:O:O', 'था:O:O', '।:O:O']

]

# %% [markdown]
# FUNCTION TO CALCULATE PRECISION RECALL AND FSCORE

# %%
def fun(sentence,list):
    true_positives = 0.0
    false_positives = 0.0
    false_negatives = 0.0
    for i in list:
        for j in i:
                w1, w2, w3 = j.split(':')
                # print(w1,w2,w3)
                if w2 == w3 and w2 == sentence:
                    true_positives += 1
                if w2 == sentence and w3 != sentence:
                    false_negatives += 1
                if w2 != sentence and w3 == sentence:
                    false_positives += 1
    if (true_positives + false_positives) != 0: 
        precision = true_positives / (true_positives + false_positives)
    else: 
        precision = 0
    if (true_positives + false_negatives) != 0: 
        recall = true_positives / (true_positives + false_negatives)
    else: 
        recall = 0
    if (precision + recall) != 0: 
        f_score = 2 * (precision * recall) / (precision + recall)
    else: 
        f_score = 0
    
    ans.append((precision,recall,f_score))

# %%
Z=['O','B-MISC','I-MISC','B-PER','I-PER','B-ORG','I-ORG','B-LOC','I-LOC']

# %%
ans=[]
fun('O',list)
fun('B-MISC',list)
fun('I-MISC',list)
fun('B-PER',list)
fun('I-PER',list)
fun('B-ORG',list)
fun('I-ORG',list)
fun('B-LOC',list)
fun('I-LOC',list)

# %% [markdown]
# PRECISION RECALL AND FSCORE OF EACH TAG (MANUAL VS CHATGPT)

# %%
print('Tags: (precision,recall,fscore)')
for i in range (0,9):
    print(Z[i],end=': ')
    print(ans[i])
# Out:
# Tags: (precision,recall,fscore)
# O: (0.9230769230769231, 0.994475138121547, 0.9574468085106383)
# B-MISC: (0.6666666666666666, 0.1111111111111111, 0.1904761904761905)
# I-MISC: (1.0, 0.18181818181818182, 0.3076923076923077)
# B-PER: (0.8888888888888888, 0.6666666666666666, 0.761904761904762)
# I-PER: (0.8888888888888888, 0.8888888888888888, 0.8888888888888888)
# B-ORG: (0.5, 0.1, 0.16666666666666669)
# I-ORG: (1.0, 0.16666666666666666, 0.2857142857142857)
# B-LOC: (0.6666666666666666, 0.5, 0.5714285714285715)
# I-LOC: (0.5, 0.3333333333333333, 0.4)

# %% [markdown]
# MACRO F1SCORE

# %%
sum=0
for i in ans:
    sum+=i[2]
print(sum/9)
# Out:
# 0.503357609031368

# %% [markdown]
# OUTPUT PRODUCED BY BERT MODEL

# %%
X=[
[('लगातार', 'O'), ('किसान', 'O'), ('इस', 'O'), ('बाबत', 'O'), ('जेडीए', 'B-ORG'), ('में', 'O'), ('आकर', 'O'), ('योजना', 'O'), ('को', 'O'), ('पूर्ण', 'O'), ('करने', 'O'), ('के', 'O'), ('लिये', 'O'), ('मांग', 'O'), ('कर', 'O'), ('रहे', 'O'), ('है।', 'O')],
[('राजे', 'O'), ('छह', 'O'), ('राज्यों', 'O'), ('के', 'O'), ('मुख्यमंत्रियों', 'O'), ('के', 'O'), ('साथ', 'O'), ('नीति', 'O'), ('आयोग', 'O'), ('की', 'O'), ('बैठक', 'O'), ('में', 'O'), ('भाग', 'O'), ('लेने', 'O'), ('दिल्ली', 'B-LOC'), ('आईं', 'O'), ('थी।', 'O')],
[('राजीव', 'B-PER'), ('गाँधी', 'I-PER'), ('ने', 'O'), ('प्रधान', 'O'), ('मंत्री', 'O'), ('कार्यकाल', 'O'), ('के', 'O'), ('दौरान', 'O'), ('उन्हें', 'O'), ('उत्कृष्ट', 'O'), ('कार्यों', 'O'), ('के', 'O'), ('लिए', 'O'), ('पुरस्कृत', 'O'), ('भी', 'O'), ('किया', 'O'), ('था.', 'O')],
[('कई', 'O'), ('अप्रिय', 'O'), ('घटनाओं', 'O'), ('से', 'O'), ('आपका', 'O'), ('मन', 'O'), ('खिन्न', 'O'), ('रह', 'O'), ('सकता', 'O'), ('है।', 'O')],
[('यही', 'O'), ('पानी', 'O'), ('जीवन', 'O'), ('की', 'O'), ('संभावनाओं', 'O'), ('का', 'O'), ('पता', 'O'), ('लगाने', 'O'), ('में', 'O'), ('मदद', 'O'), ('करेगा।', 'O')],
[('बता', 'O'), ('दें', 'O'), ('कि,', 'O'), ('विवेकानंद', 'B-PER'), ('रेड्डी', 'I-PER'), ('(68)', 'O'), ('को', 'O'), ('गुरुवार', 'O'), ('को', 'O'), ('अपने', 'O'), ('आवास', 'O'), ('पर', 'O'), ('संदिग्ध', 'O'), ('परिस्थितियों', 'O'), ('में', 'O'), ('मृत', 'O'), ('पाए', 'O'), ('गए', 'O'), ('थे।', 'O')],
[('कस्बे', 'O'), ('का', 'O'), ('चीनी', 'O'), ('घी', 'O'), ('के', 'O'), ('थोक', 'O'), ('व्यापारी', 'O'), ('अनिल', 'B-PER'), ('कंसल', 'I-PER'), ('ने', 'O'), ('पुलिस', 'O'), ('को', 'O'), ('दी', 'O'), ('शिकायत', 'O'), ('में', 'O'), ('बताया', 'O'), ('कि', 'O'), ('वह', 'O'), ('मंगलवार', 'O'), ('देर', 'O'), ('सायं', 'O'), ('को', 'O'), ('दुकानदारों', 'O'), ('से', 'O'), ('अपनी', 'O'), ('उगाही', 'O'), ('कर', 'O'), ('रहा', 'O'), ('था।', 'O')],
[('यहां', 'O'), ('वैसे', 'O'), ('तो', 'O'), ('कोई', 'O'), ('जातीय', 'O'), ('समीकरण', 'O'), ('नहीं', 'O'), ('है।', 'O'), ('लेकिन', 'O'), ('ग्रामीणों', 'O'), ('ने', 'O'), ('चर्चा', 'O'), ('में', 'O'), ('बताया', 'O'), ('कि', 'O'), ('इस', 'O'), ('गांव', 'O'), ('में', 'O'), ('जनप्रतिनिधि', 'O'), ('केवल', 'O'), ('चुनाव', 'O'), ('के', 'O'), ('दौरान', 'O'), ('ही', 'O'), ('आते', 'O'), ('हैं।', 'O')],
[('रिपोर्ट', 'O'), ('की', 'O'), ('माने', 'O'), ('तो', 'O'), ('इस', 'O'), ('पर', 'O'), ('एक', 'O'), ('भारतीय', 'O'), ('अधिकारी', 'O'), ('ने', 'O'), ('कहा', 'O'), ('सरकार', 'O'), ('विदेशी', 'O'), ('मोटरसाइकिलों', 'O'), ('पर', 'O'), ('आयात', 'O'), ('शुल्क', 'O'), ('अधिक', 'O'), ('लगाती', 'O'), ('है', 'O'), ('क्योंकि', 'O'), ('घरेलू', 'O'), ('उद्योग', 'O'), ('को', 'O'), ('सुरक्षा', 'O'), ('देने', 'O'), ('के', 'O'), ('लिए', 'O'), ('यह', 'O'), ('जरूरी', 'O'), ('है.', 'O')],
[('ए:', 'O'), ('कृपया', 'O'), ('अनदेखा', 'O'), ('करें', 'O'), ('कि', 'O'), ('आप', 'O'), ('कहीं', 'O'), ('और', 'O'), ('पढ़', 'O'), ('सकते', 'O'), ('हैं', 'O'), ('-', 'O'), ('कोह', 'O'), ('टच', 'O'), ('सिर्फ', 'O'), ('एक', 'O'), ('पार्टी', 'O'), ('जगह', 'O'), ('नहीं', 'O'), ('है!', 'O'), ('हां,', 'O'), ('मुख्य', 'O'), ('क्षेत्र', 'O'), ('में', 'O'), ('काफी', 'O'), ('जीवंत', 'O'), ('होने', 'O'), ('की', 'O'), ('प्रतिष्ठा', 'O'), ('है,', 'O'), ('लेकिन', 'O'), ('ऐसे', 'O'), ('कई', 'O'), ('अन्य', 'O'), ('क्षेत्र', 'O'), ('हैं', 'O'), ('जो', 'O'), ('शांतिपूर्ण,', 'O'), ('आराम', 'O'), ('से', 'O'), ('और', 'O'), ('वास्तव', 'O'), ('में', 'O'), ('मज़ेदार', 'O'), ('हैं।', 'O'), ('कृपया', 'O'), ('हमें', 'O'), ('पढ़ें', 'O'), ('होटल', 'O'), ('गाइड', 'O'), ('तथा', 'O'), ('बीच', 'O'), ('गाइड', 'O'), ('अधिक', 'O'), ('जानकारी', 'O'), ('के', 'O'), ('लिए।', 'O')],
[('शहरी', 'B-ORG'), ('विकास', 'I-ORG'), ('मंत्रालय', 'I-ORG'), ('के', 'O'), ('सचिव', 'O'), ('राजीव', 'B-PER'), ('गाबा', 'I-PER'), ('की', 'O'), ('अध्यक्षता', 'O'), ('में', 'O'), ('गठित', 'O'), ('इस', 'O'), ('अंतर-मंत्रालयी', 'B-ORG'), ('समिति', 'I-ORG'), ('ने', 'O'), ('शहर', 'O'), ('में', 'O'), ('फ्लाई-', 'O'), ('ओवर', 'O'), ('के', 'O'), ('निर्माण', 'O'), ('के', 'O'), ('बजाय', 'O'), ('मौजूदा', 'O'), ('सड़कों', 'O'), ('के', 'O'), ('सही', 'O'), ('इस्तेमाल', 'O'), ('और', 'O'), ('यातायात', 'O'), ('प्रबंधन', 'O'), ('पर', 'O'), ('जोर', 'O'), ('दिया', 'O'), ('है।', 'O')],
[('लीग', 'O'), ('के', 'O'), ('सीजन-5', 'O'), ('के', 'O'), ('मैचों', 'O'), ('की', 'O'), ('टीआरपी', 'B-ORG'), ('ने', 'O'), ('हाल', 'O'), ('ही', 'O'), ('में', 'O'), ('भारत', 'B-LOC'), ('और', 'O'), ('श्रीलंका', 'B-LOC'), ('के', 'O'), ('बीच', 'O'), ('हुई', 'O'), ('टेस्ट', 'O'), ('सीरीज', 'O'), ('के', 'O'), ('दर्शकों', 'O'), ('की', 'O'), ('संख्या', 'O'), ('को', 'O'), ('पीछे', 'O'), ('कर', 'O'), ('दिया।', 'O')],
[('दूसरा', 'O'), ('पहलू', 'O'), ('है-', 'O'), ('क़ानून-व्यवस्था', 'O'), ('के', 'O'), ('संभालने', 'O'), ('में', 'O'), ('राज्य', 'O'), ('और', 'O'), ('स्थानीय', 'O'), ('प्रशासन', 'O'), ('की', 'O'), ('विफलता।', 'O')],
[('वहीं', 'O'), ('आईसीआईसीआई', 'B-ORG'), ('बैंक', 'I-ORG'), ('के', 'O'), ('लिए', 'O'), ('ब्रोकरेज', 'B-ORG'), ('फर्म', 'I-ORG'), ('ने', 'O'), ('रेटिंग', 'O'), ('इक्वल-वेट', 'O'), ('से', 'O'), ('घटाकर', 'O'), ('अंडरवेट', 'O'), ('करने', 'O'), ('के', 'O'), ('साथ', 'O'), ('साथ', 'O'), ('वित्त', 'O'), ('वर्ष', 'O'), ('2018', 'O'), ('और', 'O'), ('वित्त', 'O'), ('वर्ष', 'O'), ('2019', 'O'), ('के', 'O'), ('लिए', 'O'), ('', 'O'), ('आय', 'O'), ('अनुमानों', 'O'), ('को', 'O'), ('7', 'O'), ('और', 'O'), ('5', 'O'), ('प्रतिशत', 'O'), ('तक', 'O'), ('घटा', 'O'), ('दिया', 'O'), ('है।', 'O')],
[('ऑस्ट्रेलिया', 'B-LOC'), ('ने', 'O'), ('पहले', 'O'), ('बल्लेबाजी', 'O'), ('करते', 'O'), ('हुए', 'O'), ('निर्धारित', 'O'), ('50', 'O'), ('ओवर', 'O'), ('में', 'O'), ('272', 'O'), ('रनों', 'O'), ('का', 'O'), ('विशाल', 'O'), ('स्कोर', 'O'), ('खड़ा', 'O'), ('किया', 'O'), ('था।', 'O'), ('सचिन', 'O'), ('की', 'O'), ('लाजवाब', 'O'), ('पारी', 'O'), ('के', 'O'), ('दम', 'O'), ('पर', 'O'), ('भारत', 'B-LOC'), ('ने', 'O'), ('यह', 'O'), ('स्कोर', 'O'), ('सिर्फ', 'O'), ('48.3', 'O'), ('ओवर', 'O'), ('में', 'O'), ('275', 'O'), ('रन', 'O'), ('बनाकर', 'O'), ('हासिल', 'O'), ('कर', 'O'), ('लिया', 'O'), ('था', 'O')],
[('या', 'O'), ('गाण्यांच्या', 'O'), ('लाँचिंगमध्ये', 'O'), ('शिवसेना', 'B-ORG'), ('पक्षप्रमुख', 'O'), ('उद्धव', 'B-PER'), ('ठाकरे,', 'I-PER'), ('रश्मी', 'B-PER'), ('ठाकरे,', 'I-PER'), ('आदित्य', 'B-PER'), ('ठाकरे', 'I-PER'), ('आणि', 'O'), ('सिनेमातील', 'I-PER'), ('कलाकर', 'O'), ('नवाजुद्दीन', 'B-PER'), ('सिद्दिकी,', 'I-PER'), ('अमृता', 'B-PER'), ('राव', 'I-PER'), ('यांच्यासह', 'I-PER'), ('इतर', 'O'), ('मंडळींनीही', 'O'), ('हाजेरी', 'O'), ('लावली', 'O'), ('होती.', 'O')],
[('कंपनी', 'O'), ('फिलहाल', 'O'), ('अपने', 'O'), ('ट्रांसमिशन', 'O'), ('कारोबार', 'O'), ('को', 'O'), ('बेचने', 'O'), ('पर', 'O'), ('विचार', 'O'), ('कर', 'O'), ('रही', 'O'), ('है।', 'O')],
[('इस', 'O'), ('तरह', 'O'), ('इसमें', 'O'), ('खेल', 'O'), ('रहे', 'O'), ('हर', 'O'), ('दूसरे', 'O'), ('खिलाड़ी', 'O'), ('के', 'O'), ('डोप', 'O'), ('परीक्षण', 'O'), ('की', 'O'), ('मुकम्मल', 'O'), ('व्यवस्था', 'O'), ('तैयार', 'O'), ('कर', 'O'), ('ली', 'O'), ('गई', 'O'), ('है।', 'O')],
[('इस', 'O'), ('बार', 'O'), ('गुरुवार', 'O'), ('को', 'O'), ('ईसाई', 'O'), ('समुदाय', 'O'), ('के', 'O'), ('लोगों', 'O'), ('ने', 'O'), ('यहां', 'O'), ('‘मुर्दों', 'O'), ('की', 'O'), ('ईद’', 'O'), ('मनाई।', 'O')],
[('अगर', 'O'), ('जनता', 'O'), ('इनको', 'O'), ('गंभीरता', 'O'), ('से', 'O'), ('लेगी', 'O'), ('तो', 'O'), ('निश्चित', 'O'), ('तौर', 'O'), ('पर', 'O'), ('चुनाव', 'O'), ('में', 'O'), ('इन', 'O'), ('मुद्दों', 'O'), ('की', 'O'), ('गूंज', 'O'), ('सुनाई', 'O'), ('देने', 'O'), ('लगेगी.', 'O')],
[('मशीन', 'O'), ('के', 'O'), ('माध्यम', 'O'), ('से', 'O'), ('इसकी', 'O'), ('पैकिंग', 'O'), ('ऑटोमेटिक', 'O'), ('रूप', 'O'), ('से', 'O'), ('होती', 'O'), ('है', 'O'), ('जिसमे', 'O'), ('अगरबत्तियों', 'O'), ('की', 'O'), ('गिनती', 'O'), ('होते', 'O'), ('हुए', 'O'), ('प्लास्टिक', 'O'), ('पाउच', 'O'), ('में', 'O'), ('भरने', 'O'), ('की', 'O'), ('प्रक्रिया', 'O'), ('अपने', 'O'), ('आप', 'O'), ('होती', 'O'), ('है,', 'O'), ('अन्यथा', 'O'), ('एक', 'O'), ('अगरबत्ती', 'O'), ('की', 'O'), ('गिनती', 'O'), ('के', 'O'), ('लिए', 'O'), ('मैन्युअल', 'O'), ('मशीन', 'O'), ('भी', 'O'), ('आती', 'O'), ('है', 'O'), ('जिससे', 'O'), ('सिर्फ', 'O'), ('अगरबत्ती', 'O'), ('की', 'O'), ('गिनती', 'O'), ('होती', 'O'), ('है', 'O'), ('बाकि', 'O'), ('प्रक्रिया', 'O'), ('हाथों', 'O'), ('के', 'O'), ('माध्यम', 'O'), ('से', 'O'), ('होती', 'O'), ('है.', 'O')],
[('जबकि', 'O'), ('राज्यसभा', 'B-ORG'), ('के', 'O'), ('द्वारा', 'O'), ('पारित', 'O'), ('विधेयक', 'O'), ('या', 'O'), ('प्रस्ताव', 'O'), ('लोकसभा', 'B-ORG'), ('के', 'O'), ('भंग', 'O'), ('होने', 'O'), ('की', 'O'), ('स्थिति', 'O'), ('में', 'O'), ('समाप्त', 'O'), ('नहीं', 'O'), ('होते', 'O'), ('है।', 'O')],
[('उत्तर', 'B-LOC'), ('प्रदेश', 'I-LOC'), ('में', 'O'), ('मऊ', 'B-LOC'), ('के', 'O'), ('मोहम्मदाबाद', 'B-LOC'), ('गोहना', 'O'), ('कोतवाली', 'O'), ('क्षेत्र', 'O'), ('बंद', 'O'), ('रेलवे', 'O'), ('क्रासिंग', 'O'), ('को', 'O'), ('पहले', 'O'), ('पार', 'O'), ('करने', 'O'), ('में', 'O'), ('हुये', 'O'), ('मामूली', 'O'), ('विवाद', 'O'), ('में', 'O'), ('एक', 'O'), ('युवक', 'O'), ('को', 'O'), ('गोली', 'O'), ('मार', 'O'), ('दी', 'O'), ('गयी।', 'O')],
[('उन्होंने', 'O'), ('कहा', 'O'), ('कि', 'O'), ('वह', 'O'), ('सरकार', 'O'), ('को', 'O'), ('अस्थिर', 'O'), ('करने', 'O'), ('के', 'O'), ('लिए', 'O'), ('कोई', 'O'), ('खेल', 'O'), ('नहीं', 'O'), ('खेल', 'O'), ('रहे', 'O'), ('हैं।', 'O')],
[('टीवी', 'O'), ('सीरियर', 'O'), ('और', 'O'), ('फिल्मों', 'O'), ('में', 'O'), ('रावण', 'B-PER'), ('को', 'O'), ('बहुत', 'O'), ('डरावना', 'O'), ('बताया', 'O'), ('गया', 'O'), ('है,', 'O'), ('लेकिन', 'O'), ('वास्तव', 'O'), ('में', 'O'), ('ऐसा', 'O'), ('नहीं', 'O'), ('था।', 'O')]
]

# %% [markdown]
# list IS LIST OF LIST IN WHICH EACH WORD IS STORED AS 'लगातार:O:O' WHERE लगातार IS WORD O NER TAG GIVEN BY US ANS O NER TAG GIVEN BY INDICBERT MODEL

# %%
list2=[
    ['लगातार:O:O', 'किसान:O:O', 'इस:O:O', 'बाबत:O:O', 'जेडीए:O:B-ORG', 'में:O:O', 'आकर:O:O', 'योजना:O:O', 'को:O:O', 'पूर्ण:O:O', 'करने:O:O', 'के:O:O', 'लिये:O:O', 'मांग:O:O', 'कर:O:O', 'रहे:O:O', 'है।:O:O'],
    ['राजे:B-PER:O', 'छह:B-MISC:O', 'राज्यों:O:O', 'के:O:O', 'मुख्यमंत्रियों:O:O', 'के:O:O', 'साथ:O:O', 'नीति:B-ORG:B-O', 'आयोग:O:O', 'की:O:O', 'बैठक:O:O', 'में:O:O', 'भाग:O:O', 'लेने:O:O', 'दिल्ली:B-LOC:B-LOC', 'आईं:O:O', 'थीं।:O:O'],
    ['राजीव:B-PER:B-PER', 'गाँधी:I-PER:I-PER', 'ने:O:O', 'प्रधान:B-MISC:O', 'मंत्री:I-MISC:O', 'कार्यकाल:O:O', 'के:O:O', 'दौरान:O:O', 'उन्हें:O:O', 'उत्कृष्ट:O:O', 'कार्यों:O:O', 'के:O:O', 'लिए:O:O', 'पुरस्कृत:O:O', 'भी:O:O', 'किया:O:O', 'था।:O:O'],
    ['कई:O:O', 'अप्रिय:O:O', 'घटनाओं:O:O', 'से:O:O', 'आपका:O:O', 'मन:O:O', 'खिन्न:O:O', 'रह:O:O', 'सकता:O:O', 'है।:O:O'],
    ['यही:O:O', 'पानी:O:O', 'जीवन:O:O', 'की:O:O', 'संभावनाओं:O:O', 'का:O:O', 'पता:O:O', 'लगाने:O:O', 'में:O:O', 'मदद:O:O', 'करेगा।:O:O'],
    ['बता:O:O', 'दें:O:O', 'कि:O:O', 'विवेकानंद:B-PER:B-PER', 'रेड्डी:I-PER:I-PER', '(68):B-MISC:O', 'को:O:O', 'गुरुवार:B-MISC:O', 'को:O:O', 'अपने:O:O', 'आवास:O:O', 'पर:O:O', 'संदिग्ध:O:O', 'परिस्थितियों:O:O', 'में:O:O', 'मृत:O:O', 'पाए:O:O', 'गए:O:O', 'थे।:O:O'],
    ['कस्बे:O:O', 'का:O:O', 'चीनी:B-MISC:O', 'घी:I-MISC:O', 'के:O:O', 'थोक:O:O', 'व्यापारी:O:O', 'अनिल:B-PER:B-PER', 'कंसल:I-PER:I-PER', 'ने:O:O', 'पुलिस:O:O', 'को:O:O', 'दी:O:O', 'शिकायत:O:O', 'में:O:O', 'बताया:O:O', 'कि:O:O', 'वह:O:O', 'मंगलवार:B-MISC:O', 'देर:B-MISC:O', 'सायं:B-MISC:O', 'को:O:O', 'दुकानदारों:O:O', 'से:O:O', 'अपनी:O:O', 'उगाही:O:O', 'कर:O:O', 'रहा:O:O', 'था।:O:O'],
    ['यहां:O:O', 'वैसे:O:O', 'तो:O:O', 'कोई:O:O', 'जातीय:O:O', 'समीकरण:O:O', 'नहीं:O:O', 'है:O:O', 'लेकिन:O:O', 'ग्रामीणों:O:O', 'ने:O:O', 'चर्चा:O:O', 'में:O:O', 'बताया:O:O', 'कि:O:O', 'इस:O:O', 'गांव:O:O', 'में:O:O', 'जनप्रतिनिधि:O:O', 'केवल:O:O', 'चुनाव:O:O', 'के:O:O', 'दौरान:O:O', 'ही:O:O', 'आते:O:O', 'हैं।:O:O'],
    ['रिपोर्ट:O:O', 'की:O:O', 'माने:O:O', 'तो:O:O', 'इस:O:O', 'पर:O:O', 'एक:O:O', 'भारतीय:O:O', 'अधिकारी:O:O', 'ने:O:O', 'कहा:O:O', 'सरकार:O:O', 'विदेशी:O:O', 'मोटरसाइकिलों:O:O', 'पर:O:O', 'आयात:O:O', 'शुल्क:O:O', 'अधिक:O:O', 'लगाती:O:O', 'है:O:O', 'क्योंकि:O:O', 'घरेलू:O:O', 'उद्योग:O:O', 'को:O:O', 'सुरक्षा:O:O', 'देने:O:O', 'के:O:O', 'लिए:O:O', 'यह:O:O', 'जरूरी:O:O', 'है।:O:O'],
    ['ए:O:O', 'कृपया:O:O', 'अनदेखा:O:O', 'करें:O:O', 'कि:O:O', 'आप:O:O', 'कहीं:O:O', 'और:O:O', 'पढ़:O:O', 'सकते:O:O', 'हैं:O:O', '-:O:O', 'कोह:O:O', 'टच:O:O', 'सिर्फ:O:O', 'एक:O:O', 'पार्टी:O:O', 'जगह:O:O', 'नहीं:O:O', 'है!:O:O', 'हां,:O:O', 'मुख्य:O:O', 'क्षेत्र:O:O', 'में:O:O', 'काफी:O:O', 'जीवंत:O:O', 'होने:O:O', 'की:O:O', 'प्रतिष्ठा:O:O', 'है,:O:O', 'लेकिन:O:O', 'ऐसे:O:O', 'कई:O:O', 'अन्य:O:O', 'क्षेत्र:O:O', 'हैं:O:O', 'जो:O:O', 'शांतिपूर्ण,:O:O', 'आराम:O:O', 'से:O:O', 'और:O:O', 'वास्तव:O:O', 'में:O:O', 'मज़ेदार:O:O', 'हैं।:O:O', 'कृपया:O:O', 'हमें:O:O', 'पढ़ें:O:O', 'होटल:O:O', 'गाइड:O:O', 'तथा:O:O', 'बीच:O:O', 'गाइड:O:O', 'अधिक:O:O', 'जानकारी:O:O', 'के:O:O', 'लिए।:O:O'],
    ['शहरी:O:B-ORG', 'विकास:B-ORG:I-ORG', 'मंत्रालय:I-ORG:I-ORG', 'के:O:O', 'सचिव:O:O', 'राजीव:B-PER:B-PER', 'गाबा:I-PER:I-PER', 'की:O:O', 'अध्यक्षता:O:O', 'में:O:O', 'गठित:O:O', 'इस:O:O', 'अंतर-मंत्रालयी:B-ORG:B-ORG', 'समिति:I-ORG:I-ORG', 'ने:O:O', 'शहर:O:O', 'में:O:O', 'फ्लाई-:O:O', 'ओवर:O:O', 'के:O:O', 'निर्माण:O:O', 'के:O:O', 'बजाय:O:O', 'मौजूदा:O:O', 'सड़कों:O:O', 'के:O:O', 'सही:O:O', 'इस्तेमाल:O:O', 'और:O:O', 'यातायात:O:O', 'प्रबंधन:O:O', 'पर:O:O', 'जोर:O:O', 'दिया:O:O', 'है।:O:O'],
    ['लीग:O:O', 'के:O:O', 'सीजन-5:O:O', 'के:O:O', 'मैचों:O:O', 'की:O:O', 'टीआरपी:O:B-ORG', 'ने:O:O', 'हाल:O:O', 'ही:O:O', 'में:O:O', 'भारत:B-ORG:B-LOC', 'और:O:O', 'श्रीलंका:I-ORG:B-LOC', 'के:O:O', 'बीच:O:O', 'हुई:O:O', 'टेस्ट:O:O', 'सीरीज:O:O', 'के:O:O', 'दर्शकों:O:O', 'की:O:O', 'संख्या:O:O', 'को:O:O', 'पीछे:O:O', 'कर:O:O', 'दिया।:O:O'],
    ['दूसरा:B-MISC:O', 'पहलू:O:O', 'है:O:O', 'क़ानून-व्यवस्था:O:O', 'के:O:O', 'संभालने:O:O', 'में:O:O', 'राज्य:O:O', 'और:O:O', 'स्थानीय:O:O', 'प्रशासन:O:O', 'की:O:O', 'विफलता।:O:O'],
    ['ऑस्ट्रेलिया:B-ORG:B-LOC', 'ने:O:O', 'पहले:O:O', 'बल्लेबाजी:O:O', 'करते:O:O', 'हुए:O:O', 'निर्धारित:O:O', '50:B-MISC:O', 'ओवर:O:O', 'में:O:O', '272:B-MISC:O', 'रनों:O:O', 'का:O:O', 'विशाल:O:O', 'स्कोर:O:O', 'खड़ा:O:O', 'किया:O:O', 'था:O:O', '।:O:O', 'सचिन:B-PER:O', 'की:O:O', 'लाजवाब:O:O', 'पारी:O:O', 'के:O:O', 'दम:O:O', 'पर:O:O', 'भारत:B-ORG:O', 'ने:O:O', 'यह:O:O', 'स्कोर:O:O', 'सिर्फ:O:O', '48.3:B-MISC:O', 'ओवर:O:O', 'में:O:O', '275:B-MISC:O', 'रन:O:O', 'बनाकर:O:O', 'हासिल:O:O', 'कर:O:O', 'लिया:O:O', 'था।:O:O'],
    ['या:O:O', 'गाण्यांच्या:O:O', 'लाँचिंगमध्ये:O:O', 'शिवसेना:B-MISC:B-ORG', 'पक्षप्रमुख:I-MISC:O', 'उद्धव:B-PER:B-PER', 'ठाकरे:I-PER:I-PER', 'रश्मी:B-PER:B-PER', 'ठाकरे:I-PER:I-PER', 'आदित्य:B-PER:B-PER', 'ठाकरे:I-PER:I-PER', 'आणि:O:O', 'सिनेमातील:O:I-PER', 'कलाकर:O:O', 'नवाजुद्दीन:B-PER:B-PER', 'सिद्दिकी:I-PER:I-PER', 'अमृता:B-PER:B-PER', 'राव:I-PER:I-PER', 'यांच्यासह:O:I-PER', 'इतर:O:O', 'मंडळींनीही:O:O', 'हाजेरी:O:O', 'लावली:O:O', 'होती।:O:O'],
    ['कंपनी:O:O', 'फिलहाल:O:O', 'अपने:O:O', 'ट्रांसमिशन:B-MISC:O', 'कारोबार:I-MISC:O', 'को:O:O', 'बेचने:O:O', 'पर:O:O', 'विचार:O:O', 'कर:O:O', 'रही:O:O', 'है।:O:O'],
    ['इस:O:O', 'तरह:O:O', 'इसमें:O:O', 'खेल:O:O', 'रहे:O:O', 'हर:O:O', 'दूसरे:O:O', 'खिलाड़ी:O:O', 'के:O:O', 'डोप:O:O', 'परीक्षण:O:O', 'की:O:O', 'मुकम्मल:O:O', 'व्यवस्था:O:O', 'तैयार:O:O', 'कर:O:O', 'ली:O:O', 'गई:O:O', 'है।:O:O'],
    ['इस:O:O', 'बार:O:O', 'गुरुवार:B-MISC:O', 'को:O:O', 'ईसाई:B-ORG:O', 'समुदाय:O:O', 'के:O:O', 'लोगों:O:O', 'ने:O:O', 'यहां:O:O', 'मुर्दों:B-MISC:O', 'की:I-MISC:O', 'ईद:I-MISC:O', 'मनाई।:O:O'],
    ['अगर:O:O', 'जनता:O:O', 'इनको:O:O', 'गंभीरता:O:O', 'से:O:O', 'लेगी:O:O', 'तो:O:O', 'निश्चित:O:O', 'तौर:O:O', 'पर:O:O', 'चुनाव:O:O', 'में:O:O', 'इन:O:O', 'मुद्दों:O:O', 'की:O:O', 'गूंज:O:O', 'सुनाई:O:O', 'देने:O:O', 'लगेगी।:O:O'],
    ['मशीन:O:O', 'के:O:O', 'माध्यम:O:O', 'से:O:O', 'इसकी:O:O', 'पैकिंग:O:O', 'ऑटोमेटिक:O:O', 'रूप:O:O', 'से:O:O', 'होती:O:O', 'है:O:O', 'जिसमें:O:O', 'अगरबत्तियों:O:O', 'की:O:O', 'गिनती:O:O', 'होते:O:O', 'हुए:O:O', 'प्लास्टिक:O:O', 'पाउच:O:O', 'में:O:O', 'भरने:O:O', 'की:O:O', 'प्रक्रिया:O:O', 'अपने:O:O', 'आप:O:O', 'होती:O:O', 'है:O:O', 'अन्यथा:O:O', 'एक:O:O', 'अगरबत्ती:O:O', 'की:O:O', 'गिनती:O:O', 'के:O:O', 'लिए:O:O', 'मैन्युअल:O:O', 'मशीन:O:O', 'भी:O:O', 'आती:O:O', 'है:O:O', 'जिससे:O:O', 'सिर्फ:O:O', 'अगरबत्ती:O:O', 'की:O:O', 'गिनती:O:O', 'होती:O:O', 'है:O:O', 'बाकि:O:O', 'प्रक्रिया:O:O', 'हाथों:O:O', 'के:O:O', 'माध्यम:O:O', 'से:O:O', 'होती:O:O', 'है।:O:O'],
    ['जबकि:O:O', 'राज्यसभा:B-ORG:O', 'के:O:O', 'द्वारा:O:O', 'पारित:O:O', 'विधेयक:O:O', 'या:O:O', 'प्रस्ताव:O:O', 'लोकसभा:B-ORG:O', 'के:O:O', 'भंग:O:O', 'होने:O:O', 'की:O:O', 'स्थिति:O:O', 'में:O:O', 'समाप्त:O:O', 'नहीं:O:O', 'होते:O:O', 'हैं।:O:O'],
    ['उत्तर:B-LOC:B-LOC', 'प्रदेश:I-LOC:I-LOC', 'में:O:O', 'मऊ:B-LOC:O', 'के:O:O', 'मोहम्मदाबाद:B-LOC:B-LOC', 'गोहना:I-LOC:O', 'कोतवाली:I-LOC:O', 'क्षेत्र:O:O', 'बंद:O:O', 'रेलवे:O:O', 'क्रासिंग:O:O', 'को:O:O', 'पहले:O:O', 'पार:O:O', 'करने:O:O', 'में:O:O', 'हुये:O:O', 'मामूली:O:O', 'विवाद:O:O', 'में:O:O', 'एक:O:O', 'युवक:O:O', 'को:O:O', 'गोली:O:O', 'मार:O:O', 'दी:O:O', 'गयी।:O:O'],
    ['उन्होंने:O:O', 'कहा:O:O', 'कि:O:O', 'वह:O:O', 'सरकार:O:O', 'को:O:O', 'अस्थिर:O:O', 'करने:O:O', 'के:O:O', 'लिए:O:O', 'कोई:O:O', 'खेल:O:O', 'नहीं:O:O', 'खेल:O:O', 'रहे:O:O', 'हैं।:O:O'],
    ['टीवी:O:O', 'सीरियर:O:O', 'और:O:O', 'फिल्मों:O:O', 'में:O:O', 'रावण:B-PER:B-PER', 'को:O:O', 'बहुत:O:O', 'डरावना:O:O', 'बताया:O:O', 'गया:O:O', 'है:O:O', 'लेकिन:O:O', 'वास्तव:O:O', 'में:O:O', 'ऐसा:O:O', 'नहीं:O:O', 'था।:O:O']        
]

# %%
ans=[]
fun('O',list2)
fun('B-MISC',list2)
fun('I-MISC',list2)
fun('B-PER',list2)
fun('I-PER',list2)
fun('B-ORG',list2)
fun('I-ORG',list2)
fun('B-LOC',list2)
fun('I-LOC',list2)

# %% [markdown]
# PRECISION RECALL AND FSOCRE OF EACH TAG (MANUAL VS INDICBERT MODEL)

# %%
print('Tags: (precision,recall,fscore)')
for i in range (0,9):
    print(Z[i],end=': ')
    print(ans[i])
# Out:
# Tags: (precision,recall,fscore)
# O: (0.9421641791044776, 0.9901960784313726, 0.965583173996176)
# B-MISC: (0, 0.0, 0)
# I-MISC: (0, 0.0, 0)
# B-PER: (1.0, 0.8333333333333334, 0.9090909090909091)
# I-PER: (0.8181818181818182, 1.0, 0.9)
# B-ORG: (0.2, 0.1111111111111111, 0.14285714285714285)
# I-ORG: (0.6666666666666666, 0.6666666666666666, 0.6666666666666666)
# B-LOC: (0.5, 0.75, 0.6)
# I-LOC: (1.0, 0.3333333333333333, 0.5)

# %% [markdown]
# MACRO F1 SCORE

# %%
sum=0
for i in ans:
    sum+=i[2]
print(sum/9)
# Out:
# 0.5204664325123215

# %% [markdown]
# OUTPUT PRODUCE DBY INDICNER MODEL

# %%
zzz=[[('लगातार', 'O'), ('किसान', 'O'), ('इस', 'O'), ('बाबत', 'O'), ('जेडीए', 'B-ORG'), ('में', 'O'), ('आकर', 'O'), ('योजना', 'O'), ('को', 'O'), ('पूर्ण', 'O'), ('करने', 'O'), ('के', 'O'), ('लिये', 'O'), ('मांग', 'O'), ('कर', 'O'), ('रहे', 'O'), ('है।', 'O')],
[('राजे', 'B-PER'), ('छह', 'O'), ('राज्यों', 'O'), ('के', 'O'), ('मुख्यमंत्रियों', 'O'), ('के', 'O'), ('साथ', 'O'), ('नीति', 'B-ORG'), ('आयोग', 'I-ORG'), ('की', 'O'), ('बैठक', 'O'), ('में', 'O'), ('भाग', 'O'), ('लेने', 'O'), ('दिल्ली', 'B-LOC'), ('आईं', 'O'), ('थी।', 'O')],
[('राजीव', 'B-PER'), ('गाँधी', 'I-PER'), ('ने', 'O'), ('प्रधान', 'O'), ('मंत्री', 'O'), ('कार्यकाल', 'O'), ('के', 'O'), ('दौरान', 'O'), ('उन्हें', 'O'), ('उत्कृष्ट', 'O'), ('कार्यों', 'O'), ('के', 'O'), ('लिए', 'O'), ('पुरस्कृत', 'O'), ('भी', 'O'), ('किया', 'O'), ('था.', 'O')],
[('कई', 'O'), ('अप्रिय', 'O'), ('घटनाओं', 'O'), ('से', 'O'), ('आपका', 'O'), ('मन', 'O'), ('खिन्न', 'O'), ('रह', 'O'), ('सकता', 'O'), ('है।', 'O'), ('', 'O')],
[('यही', 'O'), ('पानी', 'O'), ('जीवन', 'O'), ('की', 'O'), ('संभावनाओं', 'O'), ('का', 'O'), ('पता', 'O'), ('लगाने', 'O'), ('में', 'O'), ('मदद', 'O'), ('करेगा।', 'O')],
[('बता', 'O'), ('दें', 'O'), ('कि,', 'O'), ('विवेकानंद', 'O'), ('रेड्डी', 'B-PER'), ('(68)', 'I-PER'), ('को', 'O'), ('गुरुवार', 'O'), ('को', 'O'), ('अपने', 'O'), ('आवास', 'O'), ('पर', 'O'), ('संदिग्ध', 'O'), ('परिस्थितियों', 'O'), ('में', 'O'), ('मृत', 'O'), ('पाए', 'O'), ('गए', 'O'), ('थे।', 'O')],
[('कस्बे', 'O'), ('का', 'O'), ('चीनी', 'O'), ('घी', 'O'), ('के', 'O'), ('थोक', 'O'), ('व्यापारी', 'O'), ('अनिल', 'B-PER'), ('कंसल', 'I-PER'), ('ने', 'O'), ('पुलिस', 'O'), ('को', 'O'), ('दी', 'O'), ('शिकायत', 'O'), ('में', 'O'), ('बताया', 'O'), ('कि', 'O'), ('वह', 'O'), ('मंगलवार', 'O'), ('देर', 'O'), ('सायं', 'B-PER'), ('को', 'O'), ('दुकानदारों', 'O'), ('से', 'O'), ('अपनी', 'O'), ('उगाही', 'O'), ('कर', 'O'), ('रहा', 'O'), ('था।', 'O')],
[('यहां', 'O'), ('वैसे', 'O'), ('तो', 'O'), ('कोई', 'O'), ('जातीय', 'O'), ('समीकरण', 'O'), ('नहीं', 'O'), ('है।', 'O'), ('लेकिन', 'O'), ('ग्रामीणों', 'O'), ('ने', 'O'), ('चर्चा', 'O'), ('में', 'O'), ('बताया', 'O'), ('कि', 'O'), ('इस', 'O'), ('गांव', 'O'), ('में', 'O'), ('जनप्रतिनिधि', 'O'), ('केवल', 'O'), ('चुनाव', 'O'), ('के', 'O'), ('दौरान', 'O'), ('ही', 'O'), ('आते', 'O'), ('हैं।', 'O'), ('', 'O')],
[('रिपोर्ट', 'O'), ('की', 'O'), ('माने', 'O'), ('तो', 'O'), ('इस', 'O'), ('पर', 'O'), ('एक', 'O'), ('भारतीय', 'O'), ('अधिकारी', 'O'), ('ने', 'O'), ('कहा', 'O'), ('सरकार', 'O'), ('विदेशी', 'O'), ('मोटरसाइकिलों', 'O'), ('पर', 'O'), ('आयात', 'O'), ('शुल्क', 'O'), ('अधिक', 'O'), ('लगाती', 'O'), ('है', 'O'), ('क्योंकि', 'O'), ('घरेलू', 'O'), ('उद्योग', 'O'), ('को', 'O'), ('सुरक्षा', 'O'), ('देने', 'O'), ('के', 'O'), ('लिए', 'O'), ('यह', 'O'), ('जरूरी', 'O'), ('है.', 'O')],
[('ए:', 'O'), ('कृपया', 'O'), ('अनदेखा', 'O'), ('करें', 'O'), ('कि', 'O'), ('आप', 'O'), ('कहीं', 'O'), ('और', 'O'), ('पढ़', 'O'), ('सकते', 'O'), ('हैं', 'O'), ('-', 'O'), ('कोह', 'O'), ('टच', 'O'), ('सिर्फ', 'O'), ('एक', 'O'), ('पार्टी', 'O'), ('जगह', 'O'), ('नहीं', 'O'), ('है!', 'O'), ('हां,', 'O'), ('मुख्य', 'O'), ('क्षेत्र', 'O'), ('में', 'O'), ('काफी', 'O'), ('जीवंत', 'O'), ('होने', 'O'), ('की', 'O'), ('प्रतिष्ठा', 'O'), ('है,', 'O'), ('लेकिन', 'O'), ('ऐसे', 'O'), ('कई', 'O'), ('अन्य', 'O'), ('क्षेत्र', 'O'), ('हैं', 'O'), ('जो', 'O'), ('शांतिपूर्ण,', 'O'), ('आराम', 'O'), ('से', 'O'), ('और', 'O'), ('वास्तव', 'O'), ('में', 'O'), ('मज़ेदार', 'O'), ('हैं।', 'O'), ('कृपया', 'O'), ('हमें', 'O'), ('पढ़ें', 'O'), ('होटल', 'O'), ('गाइड', 'O'), ('तथा', 'O'), ('बीच', 'O'), ('गाइड', 'O'), ('अधिक', 'O'), ('जानकारी', 'O'), ('के', 'O'), ('लिए।', 'O')],
[('शहरी', 'B-ORG'), ('विकास', 'I-ORG'), ('मंत्रालय', 'I-ORG'), ('के', 'O'), ('सचिव', 'O'), ('राजीव', 'B-PER'), ('गाबा', 'I-PER'), ('की', 'O'), ('अध्यक्षता', 'O'), ('में', 'O'), ('गठित', 'O'), ('इस', 'O'), ('अंतर-मंत्रालयी', 'O'), ('समिति', 'O'), ('ने', 'O'), ('शहर', 'O'), ('में', 'O'), ('फ्लाई-', 'O'), ('ओवर', 'O'), ('के', 'O'), ('निर्माण', 'O'), ('के', 'O'), ('बजाय', 'O'), ('मौजूदा', 'O'), ('सड़कों', 'O'), ('के', 'O'), ('सही', 'O'), ('इस्तेमाल', 'O'), ('और', 'O'), ('यातायात', 'O'), ('प्रबंधन', 'O'), ('पर', 'O'), ('जोर', 'O'), ('दिया', 'O'), ('है।', 'O')],
[('लीग', 'O'), ('के', 'O'), ('सीजन-5', 'O'), ('के', 'O'), ('मैचों', 'O'), ('की', 'O'), ('टीआरपी', 'O'), ('ने', 'O'), ('हाल', 'B-ORG'), ('ही', 'O'), ('में', 'O'), ('भारत', 'O'), ('और', 'O'), ('श्रीलंका', 'B-LOC'), ('के', 'O'), ('बीच', 'B-LOC'), ('हुई', 'O'), ('टेस्ट', 'O'), ('सीरीज', 'O'), ('के', 'O'), ('दर्शकों', 'O'), ('की', 'O'), ('संख्या', 'O'), ('को', 'O'), ('पीछे', 'O'), ('कर', 'O'), ('दिया।', 'O')],
[('दूसरा', 'O'), ('पहलू', 'O'), ('है-', 'O'), ('क़ानून-व्यवस्था', 'O'), ('के', 'O'), ('संभालने', 'O'), ('में', 'O'), ('राज्य', 'O'), ('और', 'O'), ('स्थानीय', 'O'), ('प्रशासन', 'O'), ('की', 'O'), ('विफलता।', 'O')],
[('वहीं', 'O'), ('आईसीआईसीआई', 'B-ORG'), ('बैंक', 'I-ORG'), ('के', 'O'), ('लिए', 'O'), ('ब्रोकरेज', 'B-ORG'), ('फर्म', 'I-ORG'), ('ने', 'O'), ('रेटिंग', 'O'), ('इक्वल-वेट', 'O'), ('से', 'O'), ('घटाकर', 'O'), ('अंडरवेट', 'O'), ('करने', 'O'), ('के', 'O'), ('साथ', 'O'), ('साथ', 'O'), ('वित्त', 'O'), ('वर्ष', 'O'), ('2018', 'O'), ('और', 'O'), ('वित्त', 'O'), ('वर्ष', 'O'), ('2019', 'O'), ('के', 'O'), ('लिए', 'O'), ('', 'O'), ('आय', 'O'), ('अनुमानों', 'O'), ('को', 'O'), ('7', 'O'), ('और', 'O'), ('5', 'O'), ('प्रतिशत', 'O'), ('तक', 'O'), ('घटा', 'O'), ('दिया', 'O'), ('है।', 'O')],
[('ऑस्ट्रेलिया', 'B-LOC'), ('ने', 'O'), ('पहले', 'O'), ('बल्लेबाजी', 'O'), ('करते', 'O'), ('हुए', 'O'), ('निर्धारित', 'O'), ('50', 'O'), ('ओवर', 'O'), ('में', 'O'), ('272', 'O'), ('रनों', 'O'), ('का', 'O'), ('विशाल', 'O'), ('स्कोर', 'O'), ('खड़ा', 'O'), ('किया', 'O'), ('था।', 'O'), ('सचिन', 'O'), ('की', 'B-PER'), ('लाजवाब', 'O'), ('पारी', 'O'), ('के', 'O'), ('दम', 'O'), ('पर', 'O'), ('भारत', 'O'), ('ने', 'B-LOC'), ('यह', 'O'), ('स्कोर', 'O'), ('सिर्फ', 'O'), ('48.3', 'O'), ('ओवर', 'O'), ('में', 'O'), ('275', 'O'), ('रन', 'O'), ('बनाकर', 'O'), ('हासिल', 'O'), ('कर', 'O'), ('लिया', 'O'), ('था', 'O')],
[('या', 'O'), ('गाण्यांच्या', 'O'), ('लाँचिंगमध्ये', 'O'), ('शिवसेना', 'B-ORG'), ('पक्षप्रमुख', 'O'), ('उद्धव', 'B-PER'), ('ठाकरे,', 'I-PER'), ('रश्मी', 'O'), ('ठाकरे,', 'B-PER'), ('आदित्य', 'I-PER'), ('ठाकरे', 'O'), ('आणि', 'B-PER'), ('सिनेमातील', 'I-PER'), ('कलाकर', 'O'), ('नवाजुद्दीन', 'O'), ('सिद्दिकी,', 'O'), ('अमृता', 'B-PER'), ('राव', 'I-PER'), ('यांच्यासह', 'O'), ('इतर', 'B-PER'), ('मंडळींनीही', 'I-PER'), ('हाजेरी', 'O'), ('लावली', 'O'), ('होती.', 'O')],
[('कंपनी', 'O'), ('फिलहाल', 'O'), ('अपने', 'O'), ('ट्रांसमिशन', 'O'), ('कारोबार', 'O'), ('को', 'O'), ('बेचने', 'O'), ('पर', 'O'), ('विचार', 'O'), ('कर', 'O'), ('रही', 'O'), ('है।', 'O')],
[('इस', 'O'), ('तरह', 'O'), ('इसमें', 'O'), ('खेल', 'O'), ('रहे', 'O'), ('हर', 'O'), ('दूसरे', 'O'), ('खिलाड़ी', 'O'), ('के', 'O'), ('डोप', 'O'), ('परीक्षण', 'O'), ('की', 'O'), ('मुकम्मल', 'O'), ('व्यवस्था', 'O'), ('तैयार', 'O'), ('कर', 'O'), ('ली', 'O'), ('गई', 'O'), ('है।', 'O')],
[('इस', 'O'), ('बार', 'O'), ('गुरुवार', 'O'), ('को', 'O'), ('ईसाई', 'O'), ('समुदाय', 'O'), ('के', 'O'), ('लोगों', 'O'), ('ने', 'O'), ('यहां', 'O'), ('‘मुर्दों', 'O'), ('की', 'O'), ('ईद’', 'O'), ('मनाई।', 'O')],
[('अगर', 'O'), ('जनता', 'O'), ('इनको', 'O'), ('गंभीरता', 'O'), ('से', 'O'), ('लेगी', 'O'), ('तो', 'O'), ('निश्चित', 'O'), ('तौर', 'O'), ('पर', 'O'), ('चुनाव', 'O'), ('में', 'O'), ('इन', 'O'), ('मुद्दों', 'O'), ('की', 'O'), ('गूंज', 'O'), ('सुनाई', 'O'), ('देने', 'O'), ('लगेगी.', 'O')],
[('मशीन', 'O'), ('के', 'O'), ('माध्यम', 'O'), ('से', 'O'), ('इसकी', 'O'), ('पैकिंग', 'O'), ('ऑटोमेटिक', 'O'), ('रूप', 'O'), ('से', 'O'), ('होती', 'O'), ('है', 'O'), ('जिसमे', 'O'), ('अगरबत्तियों', 'O'), ('की', 'O'), ('गिनती', 'O'), ('होते', 'O'), ('हुए', 'O'), ('प्लास्टिक', 'O'), ('पाउच', 'O'), ('में', 'O'), ('भरने', 'O'), ('की', 'O'), ('प्रक्रिया', 'O'), ('अपने', 'O'), ('आप', 'O'), ('होती', 'O'), ('है,', 'O'), ('अन्यथा', 'O'), ('एक', 'O'), ('अगरबत्ती', 'O'), ('की', 'O'), ('गिनती', 'O'), ('के', 'O'), ('लिए', 'O'), ('मैन्युअल', 'O'), ('मशीन', 'O'), ('भी', 'O'), ('आती', 'O'), ('है', 'O'), ('जिससे', 'O'), ('सिर्फ', 'O'), ('अगरबत्ती', 'O'), ('की', 'O'), ('गिनती', 'O'), ('होती', 'O'), ('है', 'O'), ('बाकि', 'O'), ('प्रक्रिया', 'O'), ('हाथों', 'O'), ('के', 'O'), ('माध्यम', 'O'), ('से', 'O'), ('होती', 'O'), ('है.', 'O')],
[('जबकि', 'O'), ('राज्यसभा', 'B-ORG'), ('के', 'O'), ('द्वारा', 'O'), ('पारित', 'O'), ('विधेयक', 'O'), ('या', 'O'), ('प्रस्ताव', 'O'), ('लोकसभा', 'B-ORG'), ('के', 'O'), ('भंग', 'O'), ('होने', 'O'), ('की', 'O'), ('स्थिति', 'O'), ('में', 'O'), ('समाप्त', 'O'), ('नहीं', 'O'), ('होते', 'O'), ('है।', 'O')],
[('उत्तर', 'B-LOC'), ('प्रदेश', 'I-LOC'), ('में', 'O'), ('मऊ', 'B-LOC'), ('के', 'O'), ('मोहम्मदाबाद', 'B-LOC'), ('गोहना', 'I-LOC'), ('कोतवाली', 'I-LOC'), ('क्षेत्र', 'O'), ('बंद', 'O'), ('रेलवे', 'O'), ('क्रासिंग', 'O'), ('को', 'O'), ('पहले', 'O'), ('पार', 'O'), ('करने', 'O'), ('में', 'O'), ('हुये', 'O'), ('मामूली', 'O'), ('विवाद', 'O'), ('में', 'O'), ('एक', 'O'), ('युवक', 'O'), ('को', 'O'), ('गोली', 'O'), ('मार', 'O'), ('दी', 'O'), ('गयी।', 'O'), ('', 'O')],
[('उन्होंने', 'O'), ('कहा', 'O'), ('कि', 'O'), ('वह', 'O'), ('सरकार', 'O'), ('को', 'O'), ('अस्थिर', 'O'), ('करने', 'O'), ('के', 'O'), ('लिए', 'O'), ('कोई', 'O'), ('खेल', 'O'), ('नहीं', 'O'), ('खेल', 'O'), ('रहे', 'O'), ('हैं।', 'O')],
[('टीवी', 'O'), ('सीरियर', 'O'), ('और', 'O'), ('फिल्मों', 'O'), ('में', 'O'), ('रावण', 'B-PER'), ('को', 'O'), ('बहुत', 'O'), ('डरावना', 'O'), ('बताया', 'O'), ('गया', 'O'), ('है,', 'O'), ('लेकिन', 'O'), ('वास्तव', 'O'), ('में', 'O'), ('ऐसा', 'O'), ('नहीं', 'O'), ('था।', 'O')],
]

# %% [markdown]
# list IS LIST OF LIST IN WHICH EACH WORD IS STORED AS 'लगातार:O:O' WHERE लगातार IS WORD O NER TAG GIVEN BY US ANS O NER TAG GIVEN BY INDICBERT MODEL

# %%
list3 =[['लगातार:O:O', 'किसान:O:O', 'इस:O:O', 'बाबत:O:O', 'जेडीए:O:B-ORG', 'में:O:O', 'आकर:O:O', 'योजना:O:O', 'को:O:O', 'पूर्ण:O:O', 'करने:O:O', 'के:O:O', 'लिये:O:O', 'मांग:O:O', 'कर:O:O', 'रहे:O:O', 'है।:O:O'],
        ['राजे:B-PER:B-PER', 'छह:B-MISC:O', 'राज्यों:O:O', 'के:O:O', 'मुख्यमंत्रियों:O:O', 'के:O:O', 'साथ:O:O', 'नीति:B-ORG:B-ORG', 'आयोग:I-ORG:I-ORG', 'की:O:O', 'बैठक:O:O', 'में:O:O', 'भाग:O:O', 'लेने:O:O', 'दिल्ली:B-LOC:B-LOC', 'आईं:O:O', 'थी।:O:O'],
        ['राजीव:B-PER:B-PER', 'गाँधी:I-PER:I-PER', 'ने:O:O', 'प्रधान:B-MISC:O', 'मंत्री:I-MISC:O', 'कार्यकाल:O:O', 'के:O:O', 'दौरान:O:O', 'उन्हें:O:O', 'उत्कृष्ट:O:O', 'कार्यों:O:O', 'के:O:O', 'लिए:O:O', 'पुरस्कृत:O:O', 'भी:O:O', 'किया:O:O', 'था.:O:O'],
        ['कई:O:O', 'अप्रिय:O:O', 'घटनाओं:O:O', 'से:O:O', 'आपका:O:O', 'मन:O:O', 'खिन्न:O:O', 'रह:O:O', 'सकता:O:O', 'है।:O:O'],
        ['यही:O:O', 'पानी:O:O', 'जीवन:O:O', 'की:O:O', 'संभावनाओं:O:O', 'का:O:O', 'पता:O:O', 'लगाने:O:O', 'में:O:O', 'मदद:O:O', 'करेगा।:O:O'],
        ['बता:O:O', 'दें:O:O', 'कि,:O:O', 'विवेकानंद:B-PER:O', 'रेड्डी:I-PER:B-PER', '(68):B-MISC:I-PER', 'को:O:O', 'गुरुवार:B-MISC:O', 'को:O:O', 'अपने:O:O', 'आवास:O:O', 'पर:O:O', 'संदिग्ध:O:O', 'परिस्थितियों:O:O', 'में:O:O', 'मृत:O:O', 'पाए:O:O', 'गए:O:O', 'थे।:O:O'],
        ['कस्बे:O:O', 'का:O:O', 'चीनी:B-MISC:O', 'घी:I-MISC:O', 'के:O:O', 'थोक:O:O', 'व्यापारी:O:O', 'अनिल:B-PER:B-PER', 'कंसल:I-PER:I-PER', 'ने:O:O', 'पुलिस:O:O', 'को:O:O', 'दी:O:O', 'शिकायत:O:O', 'में:O:O', 'बताया:O:O', 'कि:O:O', 'वह:O:O', 'मंगलवार:B-MISC:O', 'देर:B-MISC:O', 'सायं:B-MISC:B-PER', 'को:O:O', 'दुकानदारों:O:O', 'से:O:O', 'अपनी:O:O', 'उगाही:O:O', 'कर:O:O', 'रहा:O:O', 'था।:O:O'],
        ['यहां:O:O', 'वैसे:O:O', 'तो:O:O', 'कोई:O:O', 'जातीय:O:O', 'समीकरण:O:O', 'नहीं:O:O', 'है।:O:O', 'लेकिन:O:O', 'ग्रामीणों:O:O', 'ने:O:O', 'चर्चा:O:O', 'में:O:O', 'बताया:O:O', 'कि:O:O', 'इस:O:O', 'गांव:O:O', 'में:O:O', 'जनप्रतिनिधि:O:O', 'केवल:O:O', 'चुनाव:O:O', 'के:O:O', 'दौरान:O:O', 'ही:O:O', 'आते:O:O', 'हैं।:O:O'],
        ['रिपोर्ट:O:O', 'की:O:O', 'माने:O:O', 'तो:O:O', 'इस:O:O', 'पर:O:O', 'एक:O:O', 'भारतीय:O:O', 'अधिकारी:O:O', 'ने:O:O', 'कहा:O:O', 'सरकार:O:O', 'विदेशी:O:O', 'मोटरसाइकिलों:O:O', 'पर:O:O', 'आयात:O:O', 'शुल्क:O:O', 'अधिक:O:O', 'लगाती:O:O', 'है:O:O', 'क्योंकि:O:O', 'घरेलू:O:O', 'उद्योग:O:O', 'को:O:O', 'सुरक्षा:O:O', 'देने:O:O', 'के:O:O', 'लिए:O:O', 'यह:O:O', 'जरूरी:O:O', 'है.:O:O'],
        ['ए:O:O', 'कृपया:O:O', 'अनदेखा:O:O', 'करें:O:O', 'कि:O:O', 'आप:O:O', 'कहीं:O:O', 'और:O:O', 'पढ़:O:O', 'सकते:O:O', 'हैं:O:O', '-:O:O', 'कोह:O:O', 'टच:O:O', 'सिर्फ:B-MISC:O', 'एक:O:O', 'पार्टी:O:O', 'जगह:O:O', 'नहीं:O:O', 'है!:O:O', 'हां,:O:O', 'मुख्य:O:O', 'क्षेत्र:O:O', 'में:O:O', 'काफी:O:O', 'जीवंत:O:O', 'होने:O:O', 'की:O:O', 'प्रतिष्ठा:O:O', 'है,:O:O', 'लेकिन:O:O', 'ऐसे:O:O', 'कई:O:O', 'अन्य:O:O', 'क्षेत्र:O:O', 'हैं:O:O', 'जो:O:O', 'शांतिपूर्ण,:O:O', 'आराम:O:O', 'से:O:O', 'और:O:O', 'वास्तव:O:O', 'में:O:O', 'मज़ेदार:O:O', 'हैं।:O:O', 'कृपया:O:O', 'हमें:O:O', 'पढ़ें:O:O', 'होटल:O:O', 'गाइड:O:O', 'तथा:O:O', 'बीच:O:O', 'गाइड:O:O', 'अधिक:O:O', 'जानकारी:O:O', 'के:O:O', 'लिए।:O:O'],
        ['शहरी:O:B-ORG', 'विकास:B-ORG:I-ORG', 'मंत्रालय:I-ORG:I-ORG', 'के:O:O', 'सचिव:O:O', 'राजीव:B-PER:B-PER', 'गाबा:I-PER:I-PER', 'की:O:O', 'अध्यक्षता:O:O', 'में:O:O', 'गठित:O:O', 'इस:O:O', 'अंतर-मंत्रालयी:B-ORG:O', 'समिति:I-ORG:O', 'ने:O:O', 'शहर:O:O', 'में:O:O', 'फ्लाई-:O:O', 'ओवर:O:O', 'के:O:O', 'निर्माण:O:O', 'के:O:O', 'बजाय:O:O', 'मौजूदा:O:O', 'सड़कों:O:O', 'के:O:O', 'सही:O:O', 'इस्तेमाल:O:O', 'और:O:O', 'यातायात:O:O', 'प्रबंधन:O:O', 'पर:O:O', 'जोर:O:O', 'दिया:O:O', 'है।:O:O'],
        ['लीग:O:O', 'के:O:O', 'सीजन-5:O:O', 'के:O:O', 'मैचों:O:O', 'की:O:O', 'टीआरपी:O:O', 'ने:O:O', 'हाल:O:B-ORG', 'ही:O:O', 'में:O:O', 'भारत:B-ORG:O', 'और:O:O', 'श्रीलंका:I-ORG:B-LOC', 'के:O:O', 'बीच:O:B-LOC', 'हुई:O:O', 'टेस्ट:O:O', 'सीरीज:O:O', 'के:O:O', 'दर्शकों:O:O', 'की:O:O', 'संख्या:O:O', 'को:O:O', 'पीछे:O:O', 'कर:O:O', 'दिया।:O:O'],
        ['दूसरा:B-MISC:O', 'पहलू:O:O', 'है-:O:O', 'क़ानून-व्यवस्था:O:O', 'के:O:O', 'संभालने:O:O', 'में:O:O', 'राज्य:O:O', 'और:O:O', 'स्थानीय:O:O', 'प्रशासन:O:O', 'की:O:O', 'विफलता।:O:O'],
        ['वहीं:O:O', 'आईसीआईसीआई:B-ORG:B-ORG', 'बैंक:I-ORG:I-ORG', 'के:O:O', 'लिए:O:O', 'ब्रोकरेज:B-ORG:B-ORG', 'फर्म:I-ORG:I-ORG', 'ने:O:O', 'रेटिंग:O:O', 'इक्वल-वेट:O:O', 'से:O:O', 'घटाकर:O:O', 'अंडरवेट:O:O', 'करने:O:O', 'के:O:O', 'साथ:O:O', 'साथ:O:O', 'वित्त:B-MISC:O', 'वर्ष:I-MISC:O', '2018:I-MISC:O', 'और:O:O', 'वित्त:B-MISC:O', 'वर्ष:I-MISC:O', '2019:I-MISC:O', 'के:O:O', 'लिए:O:O', 'आय:O:O', 'अनुमानों:O:O', 'को:O:O', '7:B-MISC:O', 'और:O:O', '5:B-MISC:O', 'प्रतिशत:O:O', 'तक:O:O', 'घटा:O:O', 'दिया:O:O', 'है।:O:O'],
        ['ऑस्ट्रेलिया:B-ORG:B-LOC', 'ने:O:O', 'पहले:O:O', 'बल्लेबाजी:O:O', 'करते:O:O', 'हुए:O:O', 'निर्धारित:O:O', '50:B-MISC:O', 'ओवर:O:O', 'में:O:O', '272:B-MISC:O', 'रनों:O:O', 'का:O:O', 'विशाल:O:O', 'स्कोर:O:O', 'खड़ा:O:O', 'किया:O:O', 'था।:O:O', 'सचिन:B-PER:O', 'की:O:B-PER', 'लाजवाब:O:O', 'पारी:O:O', 'के:O:O', 'दम:O:O', 'पर:O:O', 'भारत:B-ORG:O', 'ने:O:B-LOC', 'यह:O:O', 'स्कोर:O:O', 'सिर्फ:O:O', '48.3:B-MISC:O', 'ओवर:O:O', 'में:O:O', '275:B-MISC:O', 'रन:O:O', 'बनाकर:O:O', 'हासिल:O:O', 'कर:O:O', 'लिया:O:O', 'था:O:O'],
        ['या:O:O', 'गाण्यांच्या:O:O', 'लाँचिंगमध्ये:O:O', 'शिवसेना:B-MISC:B-ORG', 'पक्षप्रमुख:I-MISC:O', 'उद्धव:B-PER:B-PER', 'ठाकरे,:I-PER:I-PER', 'रश्मी:B-PER:O', 'ठाकरे,:I-PER:B-PER', 'आदित्य:B-PER:I-PER', 'ठाकरे:I-PER:O', 'आणि:O:B-PER', 'सिनेमातील:O:I-PER', 'कलाकर:O:O', 'नवाजुद्दीन:B-PER:O', 'सिद्दिकी,:I-PER:O', 'अमृता:B-PER:B-PER', 'राव:I-PER:I-PER', 'यांच्यासह:O:O', 'इतर:O:B-PER', 'मंडळींनीही:O:I-PER', 'हाजेरी:O:O', 'लावली:O:O', 'होती.:O:O'],
        ['कंपनी:O:O', 'फिलहाल:O:O', 'अपने:O:O', 'ट्रांसमिशन:B-MISC:O', 'कारोबार:I-MISC:O', 'को:O:O', 'बेचने:O:O', 'पर:O:O', 'विचार:O:O', 'कर:O:O', 'रही:O:O', 'है।:O:O'],
        ['इस:O:O', 'तरह:O:O', 'इसमें:O:O', 'खेल:O:O', 'रहे:O:O', 'हर:O:O', 'दूसरे:O:O', 'खिलाड़ी:O:O', 'के:O:O', 'डोप:O:O', 'परीक्षण:O:O', 'की:O:O', 'मुकम्मल:O:O', 'व्यवस्था:O:O', 'तैयार:O:O', 'कर:O:O', 'ली:O:O', 'गई:O:O', 'है।:O:O'],
        ['इस:O:O', 'बार:O:O', 'गुरुवार:B-MISC:O', 'को:O:O', 'ईसाई:B-ORG:O', 'समुदाय:O:O', 'के:O:O', 'लोगों:O:O', 'ने:O:O', 'यहां:O:O', '‘मुर्दों:B-MISC:O', 'की:I-MISC:O', 'ईद’:I-MISC:O', 'मनाई।:O:O'],
        ['अगर:O:O', 'जनता:O:O', 'इनको:O:O', 'गंभीरता:O:O', 'से:O:O', 'लेगी:O:O', 'तो:O:O', 'निश्चित:O:O', 'तौर:O:O', 'पर:O:O', 'चुनाव:O:O', 'में:O:O', 'इन:O:O', 'मुद्दों:O:O', 'की:O:O', 'गूंज:O:O', 'सुनाई:O:O', 'देने:O:O', 'लगेगी.:O:O'],
        ['मशीन:O:O', 'के:O:O', 'माध्यम:O:O', 'से:O:O', 'इसकी:O:O', 'पैकिंग:O:O', 'ऑटोमेटिक:O:O', 'रूप:O:O', 'से:O:O', 'होती:O:O', 'है:O:O', 'जिसमे:O:O', 'अगरबत्तियों:O:O', 'की:O:O', 'गिनती:O:O', 'होते:O:O', 'हुए:O:O', 'प्लास्टिक:O:O', 'पाउच:O:O', 'में:O:O', 'भरने:O:O', 'की:O:O', 'प्रक्रिया:O:O', 'अपने:O:O', 'आप:O:O', 'होती:O:O', 'है,:O:O', 'अन्यथा:O:O', 'एक:O:O', 'अगरबत्ती:O:O', 'की:O:O', 'गिनती:O:O', 'के:O:O', 'लिए:O:O', 'मैन्युअल:O:O', 'मशीन:O:O', 'भी:O:O', 'आती:O:O', 'है:O:O', 'जिससे:O:O', 'सिर्फ:O:O', 'अगरबत्ती:O:O', 'की:O:O', 'गिनती:O:O', 'होती:O:O', 'है:O:O', 'बाकि:O:O', 'प्रक्रिया:O:O', 'हाथों:O:O', 'के:O:O', 'माध्यम:O:O', 'से:O:O', 'होती:O:O', 'है.:O:O'],
        ['जबकि:O:O', 'राज्यसभा:B-ORG:B-ORG', 'के:O:O', 'द्वारा:O:O', 'पारित:O:O', 'विधेयक:O:O', 'या:O:O', 'प्रस्ताव:O:O', 'लोकसभा:B-ORG:B-ORG', 'के:O:O', 'भंग:O:O', 'होने:O:O', 'की:O:O', 'स्थिति:O:O', 'में:O:O', 'समाप्त:O:O', 'नहीं:O:O', 'होते:O:O', 'है।:O:O'],
        ['उत्तर:B-LOC:B-LOC', 'प्रदेश:I-LOC:I-LOC', 'में:O:O', 'मऊ:B-LOC:B-LOC', 'के:O:O', 'मोहम्मदाबाद:B-LOC:B-LOC', 'गोहना:I-LOC:I-LOC', 'कोतवाली:I-LOC:I-LOC', 'क्षेत्र:O:O', 'बंद:O:O', 'रेलवे:O:O', 'क्रासिंग:O:O', 'को:O:O', 'पहले:O:O', 'पार:O:O', 'करने:O:O', 'में:O:O', 'हुये:O:O', 'मामूली:O:O', 'विवाद:O:O', 'में:O:O', 'एक:O:O', 'युवक:O:O', 'को:O:O', 'गोली:O:O', 'मार:O:O', 'दी:O:O', 'गयी।:O,।:O'],
        ['उन्होंने:O:O', 'कहा:O:O', 'कि:O:O', 'वह:O:O', 'सरकार:O:O', 'को:O:O', 'अस्थिर:O:O', 'करने:O:O', 'के:O:O', 'लिए:O:O', 'कोई:O:O', 'खेल:O:O', 'नहीं:O:O', 'खेल:O:O', 'रहे:O:O', 'हैं।:O:O'],
        ['टीवी:O:O', 'सीरियर:O:O', 'और:O:O', 'फिल्मों:O:O', 'में:O:O', 'रावण:B-PER:B-PER', 'को:O:O', 'बहुत:O:O', 'डरावना:O:O', 'बताया:O:O', 'गया:O:O', 'है,:O:O', 'लेकिन:O:O', 'वास्तव:O:O', 'में:O:O', 'ऐसा:O:O', 'नहीं:O:O', 'था।:O:O']
        ]

# %%
ans=[]
fun('O',list3)
fun('B-MISC',list3)
fun('I-MISC',list3)
fun('B-PER',list3)
fun('I-PER',list3)
fun('B-ORG',list3)
fun('I-ORG',list3)
fun('B-LOC',list3)
fun('I-LOC',list3)

# %% [markdown]
# PRECISION RECALL AND FSCORE OF EACK TAG (MANUAL VS INDICNER)

# %%
print('Tags: (precision,recall,fscore)')
for i in range (0,9):
    print(Z[i],end=': ')
    print(ans[i])
# Out:
# Tags: (precision,recall,fscore)
# O: (0.9270462633451957, 0.9811676082862524, 0.9533394327538883)
# B-MISC: (0, 0.0, 0)
# I-MISC: (0, 0.0, 0)
# B-PER: (0.5384615384615384, 0.5833333333333334, 0.5599999999999999)
# I-PER: (0.5555555555555556, 0.5555555555555556, 0.5555555555555556)
# B-ORG: (0.5555555555555556, 0.45454545454545453, 0.5)
# I-ORG: (0.8, 0.6666666666666666, 0.7272727272727272)
# B-LOC: (0.5, 1.0, 0.6666666666666666)
# I-LOC: (1.0, 1.0, 1.0)

# %% [markdown]
# MACRO F1 SCORE

# %%
sum=0
for i in ans:
    sum+=i[2]
print(sum/9)
# Out:
# 0.5514260424720931
